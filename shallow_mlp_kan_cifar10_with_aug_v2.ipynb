# %% [markdown]
# <a href="https://colab.research.google.com/github/DavianYang/kan-cnn-study/blob/main/shallow_mlp_kan_cifar10_with_aug_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
from torchvision.transforms import v2
import torchvision.models as models
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import DataLoader

import math
import matplotlib.pyplot as plt
from datetime import datetime
import time
import wandb
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
# https://github.com/Blealtan/efficient-kan/tree/master/src/efficient_kan

import torch
import torch.nn.functional as F
import math


class KANLinear(torch.nn.Module):
    def __init__(
        self,
        in_features,
        out_features,
        grid_size=5,
        spline_order=3,
        scale_noise=0.1,
        scale_base=1.0,
        scale_spline=1.0,
        enable_standalone_scale_spline=True,
        base_activation=torch.nn.SiLU,
        grid_eps=0.02,
        grid_range=[-1, 1],
    ):
        super(KANLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.grid_size = grid_size
        self.spline_order = spline_order

        h = (grid_range[1] - grid_range[0]) / grid_size
        grid = (
            (
                torch.arange(-spline_order, grid_size + spline_order + 1) * h
                + grid_range[0]
            )
            .expand(in_features, -1)
            .contiguous()
        )
        self.register_buffer("grid", grid)

        self.base_weight = torch.nn.Parameter(torch.Tensor(out_features, in_features))
        self.spline_weight = torch.nn.Parameter(
            torch.Tensor(out_features, in_features, grid_size + spline_order)
        )
        if enable_standalone_scale_spline:
            self.spline_scaler = torch.nn.Parameter(
                torch.Tensor(out_features, in_features)
            )

        self.scale_noise = scale_noise
        self.scale_base = scale_base
        self.scale_spline = scale_spline
        self.enable_standalone_scale_spline = enable_standalone_scale_spline
        self.base_activation = base_activation()
        self.grid_eps = grid_eps

        self.reset_parameters()

    def reset_parameters(self):
        torch.nn.init.kaiming_uniform_(self.base_weight, a=math.sqrt(5) * self.scale_base)
        with torch.no_grad():
            noise = (
                (
                    torch.rand(self.grid_size + 1, self.in_features, self.out_features)
                    - 1 / 2
                )
                * self.scale_noise
                / self.grid_size
            )
            self.spline_weight.data.copy_(
                (self.scale_spline if not self.enable_standalone_scale_spline else 1.0)
                * self.curve2coeff(
                    self.grid.T[self.spline_order : -self.spline_order],
                    noise,
                )
            )
            if self.enable_standalone_scale_spline:
                # torch.nn.init.constant_(self.spline_scaler, self.scale_spline)
                torch.nn.init.kaiming_uniform_(self.spline_scaler, a=math.sqrt(5) * self.scale_spline)

    def b_splines(self, x: torch.Tensor):
        """
        Compute the B-spline bases for the given input tensor.

        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, in_features).

        Returns:
            torch.Tensor: B-spline bases tensor of shape (batch_size, in_features, grid_size + spline_order).
        """
        assert x.dim() == 2 and x.size(1) == self.in_features

        grid: torch.Tensor = (
            self.grid
        )  # (in_features, grid_size + 2 * spline_order + 1)
        x = x.unsqueeze(-1)
        bases = ((x >= grid[:, :-1]) & (x < grid[:, 1:])).to(x.dtype)
        for k in range(1, self.spline_order + 1):
            bases = (
                (x - grid[:, : -(k + 1)])
                / (grid[:, k:-1] - grid[:, : -(k + 1)])
                * bases[:, :, :-1]
            ) + (
                (grid[:, k + 1 :] - x)
                / (grid[:, k + 1 :] - grid[:, 1:(-k)])
                * bases[:, :, 1:]
            )

        assert bases.size() == (
            x.size(0),
            self.in_features,
            self.grid_size + self.spline_order,
        )
        return bases.contiguous()

    def curve2coeff(self, x: torch.Tensor, y: torch.Tensor):
        """
        Compute the coefficients of the curve that interpolates the given points.

        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, in_features).
            y (torch.Tensor): Output tensor of shape (batch_size, in_features, out_features).

        Returns:
            torch.Tensor: Coefficients tensor of shape (out_features, in_features, grid_size + spline_order).
        """
        assert x.dim() == 2 and x.size(1) == self.in_features
        assert y.size() == (x.size(0), self.in_features, self.out_features)

        A = self.b_splines(x).transpose(
            0, 1
        )  # (in_features, batch_size, grid_size + spline_order)
        B = y.transpose(0, 1)  # (in_features, batch_size, out_features)
        solution = torch.linalg.lstsq(
            A, B
        ).solution  # (in_features, grid_size + spline_order, out_features)
        result = solution.permute(
            2, 0, 1
        )  # (out_features, in_features, grid_size + spline_order)

        assert result.size() == (
            self.out_features,
            self.in_features,
            self.grid_size + self.spline_order,
        )
        return result.contiguous()

    @property
    def scaled_spline_weight(self):
        return self.spline_weight * (
            self.spline_scaler.unsqueeze(-1)
            if self.enable_standalone_scale_spline
            else 1.0
        )

    def forward(self, x: torch.Tensor):
        assert x.size(-1) == self.in_features
        original_shape = x.shape
        x = x.reshape(-1, self.in_features)

        base_output = F.linear(self.base_activation(x), self.base_weight)
        spline_output = F.linear(
            self.b_splines(x).view(x.size(0), -1),
            self.scaled_spline_weight.view(self.out_features, -1),
        )
        output = base_output + spline_output

        output = output.reshape(*original_shape[:-1], self.out_features)
        return output

    @torch.no_grad()
    def update_grid(self, x: torch.Tensor, margin=0.01):
        assert x.dim() == 2 and x.size(1) == self.in_features
        batch = x.size(0)

        splines = self.b_splines(x)  # (batch, in, coeff)
        splines = splines.permute(1, 0, 2)  # (in, batch, coeff)
        orig_coeff = self.scaled_spline_weight  # (out, in, coeff)
        orig_coeff = orig_coeff.permute(1, 2, 0)  # (in, coeff, out)
        unreduced_spline_output = torch.bmm(splines, orig_coeff)  # (in, batch, out)
        unreduced_spline_output = unreduced_spline_output.permute(
            1, 0, 2
        )  # (batch, in, out)

        # sort each channel individually to collect data distribution
        x_sorted = torch.sort(x, dim=0)[0]
        grid_adaptive = x_sorted[
            torch.linspace(
                0, batch - 1, self.grid_size + 1, dtype=torch.int64, device=x.device
            )
        ]

        uniform_step = (x_sorted[-1] - x_sorted[0] + 2 * margin) / self.grid_size
        grid_uniform = (
            torch.arange(
                self.grid_size + 1, dtype=torch.float32, device=x.device
            ).unsqueeze(1)
            * uniform_step
            + x_sorted[0]
            - margin
        )

        grid = self.grid_eps * grid_uniform + (1 - self.grid_eps) * grid_adaptive
        grid = torch.concatenate(
            [
                grid[:1]
                - uniform_step
                * torch.arange(self.spline_order, 0, -1, device=x.device).unsqueeze(1),
                grid,
                grid[-1:]
                + uniform_step
                * torch.arange(1, self.spline_order + 1, device=x.device).unsqueeze(1),
            ],
            dim=0,
        )

        self.grid.copy_(grid.T)
        self.spline_weight.data.copy_(self.curve2coeff(x, unreduced_spline_output))

    def regularization_loss(self, regularize_activation=1.0, regularize_entropy=1.0):
        """
        Compute the regularization loss.

        This is a dumb simulation of the original L1 regularization as stated in the
        paper, since the original one requires computing absolutes and entropy from the
        expanded (batch, in_features, out_features) intermediate tensor, which is hidden
        behind the F.linear function if we want an memory efficient implementation.

        The L1 regularization is now computed as mean absolute value of the spline
        weights. The authors implementation also includes this term in addition to the
        sample-based regularization.
        """
        l1_fake = self.spline_weight.abs().mean(-1)
        regularization_loss_activation = l1_fake.sum()
        p = l1_fake / regularization_loss_activation
        regularization_loss_entropy = -torch.sum(p * p.log())
        return (
            regularize_activation * regularization_loss_activation
            + regularize_entropy * regularization_loss_entropy
        )


class KAN(torch.nn.Module):
    def __init__(
        self,
        layers_hidden,
        grid_size=5,
        spline_order=3,
        scale_noise=0.1,
        scale_base=1.0,
        scale_spline=1.0,
        base_activation=torch.nn.SiLU,
        grid_eps=0.02,
        grid_range=[-1, 1],
    ):
        super(KAN, self).__init__()
        self.grid_size = grid_size
        self.spline_order = spline_order

        self.layers = torch.nn.ModuleList()
        for in_features, out_features in zip(layers_hidden, layers_hidden[1:]):
            self.layers.append(
                KANLinear(
                    in_features,
                    out_features,
                    grid_size=grid_size,
                    spline_order=spline_order,
                    scale_noise=scale_noise,
                    scale_base=scale_base,
                    scale_spline=scale_spline,
                    base_activation=base_activation,
                    grid_eps=grid_eps,
                    grid_range=grid_range,
                )
            )

    def forward(self, x: torch.Tensor, update_grid=False):
        for layer in self.layers:
            if update_grid:
                layer.update_grid(x)
            x = layer(x)
        return x

    def regularization_loss(self, regularize_activation=1.0, regularize_entropy=1.0):
        return sum(
            layer.regularization_loss(regularize_activation, regularize_entropy)
            for layer in self.layers
        )

# %%
# Define color codes for terminal
class Colors:
    RESET = '\033[0m'
    GREEN = '\033[92m'
    RED = '\033[91m'
    YELLOW = '\033[93m'
    CYAN = '\033[96m'

def display_progress_bar(batch_idx, num_batches, loss, accuracy):
    """
    Function to display a colored progress bar.
    Args:
        batch_idx: Current batch index
        num_batches: Total number of batches
        loss: Current loss value
        accuracy: Current accuracy value
    """
    progress = (batch_idx + 1) / num_batches
    bar_length = 40  # Length of the progress bar (number of '==' chars)
    filled_length = int(bar_length * progress)
    bar = f"{Colors.GREEN}{'=' * filled_length}{Colors.RED}{'-' * (bar_length - filled_length)}{Colors.RESET}"

    print(f'\r[{bar}] {batch_idx + 1}/{num_batches} | {Colors.YELLOW}Loss:{Colors.RESET} {loss:.3f} | {Colors.YELLOW}Accuracy:{Colors.RESET} {accuracy:.2f}%', end='', flush=True)

# %%
import matplotlib.pyplot as plt

def plot_result(history, title="Training Progress"):
    epochs = range(1, len(history['train_loss']) + 1)

    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['train_loss'], label='Train', color='tomato')
    plt.plot(epochs, history['val_loss'], label='Validation', color='steelblue')
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(frameon=False)
    plt.grid(True, linestyle="--", alpha=0.3)

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['train_acc'], label='Train', color='mediumseagreen')
    plt.plot(epochs, history['val_acc'], label='Validation', color='black')
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(frameon=False)
    plt.grid(True, linestyle="--", alpha=0.3)

    plt.suptitle(title, fontsize=14)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %%
def train_one_epoch(model, trainloader, input_dim, show_progress):
  train_loss, avg_loss = 0.0, 0.0
  correct, total = 0, 0 # for accuracy calculation
  num_train_batches = len(trainloader)

  model.train()

  for batch_idx, (inputs, targets) in enumerate(trainloader):
      # flattening input dim for KAN
      # [batch_size, 3, H, W] -> [batch_size, input_dim * input_dim *]
      if input_dim is not None:
          inputs = inputs.view(-1, input_dim * input_dim * 3).to(device)
      inputs, targets = inputs.to(device), targets.to(device)

      optimizer.zero_grad()
      outputs = model(inputs)
      loss = criterion(outputs, targets)
      loss.backward()
      optimizer.step()

      train_loss += loss.item()
      _, preds = outputs.max(1)
      total += targets.size(0)
      correct += preds.eq(targets).sum().item()

      if show_progress:
          acc = 100. * correct / total
          avg_loss = train_loss / (batch_idx + 1)
          display_progress_bar(batch_idx, num_train_batches, avg_loss, acc)

  train_epoch_loss = train_loss / num_train_batches
  train_epoch_acc = 100. * correct / total

  return train_epoch_loss, train_epoch_acc

# %%
def val_one_epoch(model, valloader, input_dim, show_progress):
  val_loss, avg_loss = 0.0, 0.0
  correct, total = 0, 0
  all_preds, all_targets = [], []
  num_val_batches = len(valloader)

  model.eval()

  with torch.no_grad():
      for batch_idx, (inputs, targets) in enumerate(valloader):

          if input_dim is not None:
              inputs = inputs.view(-1, input_dim * input_dim * 3).to(device)
          inputs, targets = inputs.to(device), targets.to(device)

          outputs = model(inputs)
          loss = criterion(outputs, targets)

          val_loss += loss.item()
          _, preds = outputs.max(1)
          total += targets.size(0)
          correct += preds.eq(targets).sum().item()

          all_preds.extend(preds.cpu().numpy())
          all_targets.extend(targets.cpu().numpy())

          if show_progress:
            acc = 100. * correct / total
            avg_loss = val_loss / (batch_idx + 1)
            display_progress_bar(batch_idx, num_val_batches, avg_loss, acc)

  val_epoch_loss = val_loss / num_val_batches
  val_epoch_acc = 100. * correct / total

  return all_preds, all_targets, val_epoch_loss, val_epoch_acc

# %%
def train_model(model, trainloader, valloader, device,
                             optimizer, criterion, epochs=10, model_name="model", input_dim=None,
                             use_wandb=False, project_name=None, show_progress=True):
    train_loss_list, train_acc_list = [], []
    val_loss_list, val_acc_list = [], []
    best_vloss = 1_000_000.
    epochs_without_improvement = 0
    patience = 20
    best_model_state =  None

    model.to(device)
    start_time = time.time()

    if use_wandb:
        wandb.init(project=project_name)
        wandb.watch(model, log="all")

    for epoch in range(epochs):
        timestamp = datetime.fromtimestamp(start_time).strftime('%Y%m%d_%H%M%S')
        model_path = f"{model_name}_{timestamp}_{epoch}.pt"

        # ---------- Training ----------
        print(f"\nEpoch {epoch + 1}/{epochs} - Training")
        train_epoch_loss, train_epoch_acc= train_one_epoch(model, trainloader, input_dim, show_progress)
        train_loss_list.append(train_epoch_loss)
        train_acc_list.append(train_epoch_acc)

        # ---------- Evaluation ----------
        print(f"\nEpoch {epoch + 1}/{epochs} - Evaluation")
        all_preds, all_targets, val_epoch_loss, val_epoch_acc = val_one_epoch(model, valloader, input_dim, show_progress)
        val_loss_list.append(val_epoch_loss)
        val_acc_list.append(val_epoch_acc)

        # Track best performance, and save the model's state
        if val_epoch_loss < best_vloss:
          best_vloss = val_epoch_loss
          best_model_state = model.state_dict()
          torch.save(best_model_state, model_path)
          epochs_without_improvement = 0
        else:
          epochs_without_improvement += 1

        # If no imporvement for "patience" number of epochs, stop early
        if epochs_without_improvement >= patience:
            print(f"\nEarly stopping at epoch {epoch+1} with best validation loss: {best_vloss:.4f}")
            model.load_state_dict(best_model_state, model_path)  # Restore the best model state
            break

        print(f"\nTrain Loss: {train_epoch_loss:.4f}, Train Acc: {train_epoch_acc:.2f}%")
        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Acc: {val_epoch_acc:.2f}%")

        if use_wandb:
            wandb.log({
                "Train Loss": train_epoch_loss,
                "Train Accuracy": train_epoch_acc,
                "Validation Loss": val_epoch_loss,
                "Validation Accuracy": val_epoch_acc,
                "Epoch": epoch + 1
            })

    elapsed = time.time() - start_time
    print(f"\nTraining complete in {elapsed // 60:.0f}m {elapsed % 60:.0f}s.")

    if use_wandb:
        wandb.finish()

    return {
        "model": model,
        "train_loss": train_loss_list,
        "train_acc": train_acc_list,
        "val_loss": val_loss_list,
        "val_acc": val_acc_list,
        "predictions": all_preds,
        "targets": all_targets
    }

# %%
def evaluate_test_set(model, testloader, device, criterion, model_path, input_dim=None):
  test_loss = 0.0
  correct, total = 0, 0
  all_preds, all_targets = [], []

  model.load_state_dict(torch.load(model_path))
  model.to(device)
  model.eval()


  with torch.no_grad():
    for inputs, targets in testloader:
          if input_dim is not None:
              inputs = inputs.view(-1, input_dim * input_dim * 3).to(device)
          inputs, targets = inputs.to(device), targets.to(device)
          outputs = model(inputs)
          loss = criterion(outputs, targets)

          test_loss += loss.item()
          _, preds = outputs.max(1)
          total += targets.size(0)
          correct += preds.eq(targets).sum().item()

          all_preds.extend(preds.cpu().numpy())
          all_targets.extend(targets.cpu().numpy())

  avg_test_loss = test_loss / len(testloader)
  test_acc = 100. * correct / total

  print(f"\nTest Loss: {avg_test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

  return avg_test_loss, test_acc, all_preds, all_targets

# %%
def count_parameters(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total_params, trainable_params

# %%
class ShallowNet(nn.Module):
  def __init__(self, height, width, depth, classes):
    super(ShallowNet, self).__init__()

    self.conv1 = nn.Conv2d(in_channels=depth, out_channels=32, kernel_size=3, padding='same')
    self.fc1 = nn.Linear(32 * height * width, classes)

  def forward(self, x):
    x = self.conv1(x)
    x = F.relu(x)
    x = torch.flatten(x, 1)
    x = self.fc1(x)

    return x

# %%
classes = 10
input_dim = 32
lr = 0.001
epochs = 100
batch_size = 64

torch.manual_seed(42)

transform = v2.Compose([
    v2.RandomCrop(32, padding=4),
    v2.RandomHorizontalFlip(),
    v2.ToTensor(),
    v2.Normalize(mean=[0.4914, 0.4822, 0.4465],
                         std=[0.2023, 0.1994, 0.2010]),
])

# Load CIFAR-10 dataset
full_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

train_size = int(0.8 * len(full_dataset)) # 80% for training
val_size = len(full_dataset) - train_size # 20% for validation

trainset, valset = torch.utils.data.random_split(full_dataset, [train_size, val_size])

trainloader = DataLoader(trainset, batch_size, shuffle=True)
valloader = DataLoader(valset, batch_size, shuffle=False)
testloader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
shallow_mlp = ShallowNet(height=32, width=32, depth=3, classes=10)

total_params_mlp, trainable_params_mlp = count_parameters(shallow_mlp)
print(f"Total parameters: {total_params_mlp}")
print(f"Trainable parameters: {trainable_params_mlp}")

optimizer = optim.AdamW(shallow_mlp.parameters(), lr=lr,weight_decay=0.01)
criterion = nn.CrossEntropyLoss()
# Out:
# Total parameters: 328586
# Trainable parameters: 328586

# %%
result = train_model(shallow_mlp, trainloader, valloader, device, optimizer, criterion, epochs, model_name="MLP")
# Out:
# Epoch 1/100 - Training
# [========================================] 625/625 | Loss: 1.816 | Accuracy: 39.37%
# Epoch 1/100 - Evaluation
# [========================================] 157/157 | Loss: 1.573 | Accuracy: 45.00%
# Train Loss: 1.8155, Train Acc: 39.37%
# Validation Loss: 1.5727, Validation Acc: 45.00%
#
# Epoch 2/100 - Training
# [========================================] 625/625 | Loss: 1.463 | Accuracy: 48.28%
# Epoch 2/100 - Evaluation
# [========================================] 157/157 | Loss: 1.455 | Accuracy: 48.24%
# Train Loss: 1.4631, Train Acc: 48.28%
# Validation Loss: 1.4551, Validation Acc: 48.24%
#
# Epoch 3/100 - Training
# [========================================] 625/625 | Loss: 1.379 | Accuracy: 51.44%
# Epoch 3/100 - Evaluation
# [========================================] 157/157 | Loss: 1.363 | Accuracy: 52.38%
# Train Loss: 1.3791, Train Acc: 51.44%
# Validation Loss: 1.3631, Validation Acc: 52.38%
#
# Epoch 4/100 - Training
# [========================================] 625/625 | Loss: 1.333 | Accuracy: 53.74%
# Epoch 4/100 - Evaluation
# [========================================] 157/157 | Loss: 1.343 | Accuracy: 54.31%
# Train Loss: 1.3332, Train Acc: 53.74%
# Validation Loss: 1.3428, Validation Acc: 54.31%
#
# Epoch 5/100 - Training
# [========================================] 625/625 | Loss: 1.307 | Accuracy: 54.24%
# Epoch 5/100 - Evaluation
# [========================================] 157/157 | Loss: 1.344 | Accuracy: 53.53%
# Train Loss: 1.3066, Train Acc: 54.24%
# Validation Loss: 1.3442, Validation Acc: 53.53%
#
# Epoch 6/100 - Training
# [========================================] 625/625 | Loss: 1.295 | Accuracy: 54.87%
# Epoch 6/100 - Evaluation
# [========================================] 157/157 | Loss: 1.334 | Accuracy: 54.33%
# Train Loss: 1.2953, Train Acc: 54.87%
# Validation Loss: 1.3342, Validation Acc: 54.33%
#
# Epoch 7/100 - Training
# [========================================] 625/625 | Loss: 1.278 | Accuracy: 55.92%
# Epoch 7/100 - Evaluation
# [========================================] 157/157 | Loss: 1.339 | Accuracy: 53.87%
# Train Loss: 1.2780, Train Acc: 55.92%
# Validation Loss: 1.3391, Validation Acc: 53.87%
#
# Epoch 8/100 - Training
# [========================================] 625/625 | Loss: 1.268 | Accuracy: 56.34%
# Epoch 8/100 - Evaluation
# [========================================] 157/157 | Loss: 1.316 | Accuracy: 54.73%
# Train Loss: 1.2683, Train Acc: 56.34%
# Validation Loss: 1.3164, Validation Acc: 54.73%
#
# Epoch 9/100 - Training
# [========================================] 625/625 | Loss: 1.259 | Accuracy: 56.63%
# Epoch 9/100 - Evaluation
# [========================================] 157/157 | Loss: 1.280 | Accuracy: 56.49%
# Train Loss: 1.2593, Train Acc: 56.63%
# Validation Loss: 1.2797, Validation Acc: 56.49%
#
# Epoch 10/100 - Training
# [========================================] 625/625 | Loss: 1.253 | Accuracy: 56.77%
# Epoch 10/100 - Evaluation
# [========================================] 157/157 | Loss: 1.310 | Accuracy: 55.13%
# Train Loss: 1.2535, Train Acc: 56.77%
# Validation Loss: 1.3098, Validation Acc: 55.13%
#
# Epoch 11/100 - Training
# [========================================] 625/625 | Loss: 1.239 | Accuracy: 57.09%
# Epoch 11/100 - Evaluation
# [========================================] 157/157 | Loss: 1.254 | Accuracy: 57.75%
# Train Loss: 1.2390, Train Acc: 57.09%
# Validation Loss: 1.2545, Validation Acc: 57.75%
#
# Epoch 12/100 - Training
# [========================================] 625/625 | Loss: 1.234 | Accuracy: 57.74%
# Epoch 12/100 - Evaluation
# [========================================] 157/157 | Loss: 1.269 | Accuracy: 57.03%
# Train Loss: 1.2341, Train Acc: 57.74%
# Validation Loss: 1.2689, Validation Acc: 57.03%
#
# Epoch 13/100 - Training
# [========================================] 625/625 | Loss: 1.228 | Accuracy: 57.87%
# Epoch 13/100 - Evaluation
# [========================================] 157/157 | Loss: 1.247 | Accuracy: 57.35%
# Train Loss: 1.2280, Train Acc: 57.87%
# Validation Loss: 1.2470, Validation Acc: 57.35%
#
# Epoch 14/100 - Training
# [========================================] 625/625 | Loss: 1.228 | Accuracy: 57.77%
# Epoch 14/100 - Evaluation
# [========================================] 157/157 | Loss: 1.302 | Accuracy: 55.82%
# Train Loss: 1.2275, Train Acc: 57.77%
# Validation Loss: 1.3019, Validation Acc: 55.82%
#
# Epoch 15/100 - Training
# [========================================] 625/625 | Loss: 1.220 | Accuracy: 58.30%
# Epoch 15/100 - Evaluation
# [========================================] 157/157 | Loss: 1.267 | Accuracy: 56.29%
# Train Loss: 1.2197, Train Acc: 58.30%
# Validation Loss: 1.2666, Validation Acc: 56.29%
#
# Epoch 16/100 - Training
# [========================================] 625/625 | Loss: 1.209 | Accuracy: 58.09%
# Epoch 16/100 - Evaluation
# [========================================] 157/157 | Loss: 1.247 | Accuracy: 57.68%
# Train Loss: 1.2088, Train Acc: 58.09%
# Validation Loss: 1.2468, Validation Acc: 57.68%
#
# Epoch 17/100 - Training
# [========================================] 625/625 | Loss: 1.204 | Accuracy: 58.68%
# Epoch 17/100 - Evaluation
# [========================================] 157/157 | Loss: 1.259 | Accuracy: 57.80%
# Train Loss: 1.2040, Train Acc: 58.68%
# Validation Loss: 1.2592, Validation Acc: 57.80%
#
# Epoch 18/100 - Training
# [========================================] 625/625 | Loss: 1.207 | Accuracy: 58.52%
# Epoch 18/100 - Evaluation
# [========================================] 157/157 | Loss: 1.240 | Accuracy: 57.68%
# Train Loss: 1.2073, Train Acc: 58.52%
# Validation Loss: 1.2404, Validation Acc: 57.68%
#
# Epoch 19/100 - Training
# [========================================] 625/625 | Loss: 1.207 | Accuracy: 58.56%
# Epoch 19/100 - Evaluation
# [========================================] 157/157 | Loss: 1.242 | Accuracy: 58.06%
# Train Loss: 1.2067, Train Acc: 58.56%
# Validation Loss: 1.2423, Validation Acc: 58.06%
#
# Epoch 20/100 - Training
# [========================================] 625/625 | Loss: 1.201 | Accuracy: 58.98%
# Epoch 20/100 - Evaluation
# [========================================] 157/157 | Loss: 1.260 | Accuracy: 56.96%
# Train Loss: 1.2013, Train Acc: 58.98%
# Validation Loss: 1.2605, Validation Acc: 56.96%
#
# Epoch 21/100 - Training
# [========================================] 625/625 | Loss: 1.198 | Accuracy: 58.93%
# Epoch 21/100 - Evaluation
# [========================================] 157/157 | Loss: 1.248 | Accuracy: 57.04%
# Train Loss: 1.1978, Train Acc: 58.93%
# Validation Loss: 1.2483, Validation Acc: 57.04%
#
# Epoch 22/100 - Training
# [========================================] 625/625 | Loss: 1.193 | Accuracy: 59.18%
# Epoch 22/100 - Evaluation
# [========================================] 157/157 | Loss: 1.237 | Accuracy: 57.68%
# Train Loss: 1.1929, Train Acc: 59.18%
# Validation Loss: 1.2371, Validation Acc: 57.68%
#
# Epoch 23/100 - Training
# [========================================] 625/625 | Loss: 1.191 | Accuracy: 59.44%
# Epoch 23/100 - Evaluation
# [========================================] 157/157 | Loss: 1.265 | Accuracy: 56.64%
# Train Loss: 1.1907, Train Acc: 59.44%
# Validation Loss: 1.2655, Validation Acc: 56.64%
#
# Epoch 24/100 - Training
# [========================================] 625/625 | Loss: 1.191 | Accuracy: 59.21%
# Epoch 24/100 - Evaluation
# [========================================] 157/157 | Loss: 1.242 | Accuracy: 58.40%
# Train Loss: 1.1912, Train Acc: 59.21%
# Validation Loss: 1.2420, Validation Acc: 58.40%
#
# Epoch 25/100 - Training
# [========================================] 625/625 | Loss: 1.180 | Accuracy: 59.63%
# Epoch 25/100 - Evaluation
# [========================================] 157/157 | Loss: 1.231 | Accuracy: 57.97%
# Train Loss: 1.1798, Train Acc: 59.63%
# Validation Loss: 1.2306, Validation Acc: 57.97%
#
# Epoch 26/100 - Training
# [========================================] 625/625 | Loss: 1.184 | Accuracy: 59.52%
# Epoch 26/100 - Evaluation
# [========================================] 157/157 | Loss: 1.228 | Accuracy: 58.71%
# Train Loss: 1.1840, Train Acc: 59.52%
# Validation Loss: 1.2284, Validation Acc: 58.71%
#
# Epoch 27/100 - Training
# [========================================] 625/625 | Loss: 1.183 | Accuracy: 59.41%
# Epoch 27/100 - Evaluation
# [========================================] 157/157 | Loss: 1.242 | Accuracy: 58.06%
# Train Loss: 1.1827, Train Acc: 59.41%
# Validation Loss: 1.2424, Validation Acc: 58.06%
#
# Epoch 28/100 - Training
# [========================================] 625/625 | Loss: 1.177 | Accuracy: 59.66%
# Epoch 28/100 - Evaluation
# [========================================] 157/157 | Loss: 1.212 | Accuracy: 58.88%
# Train Loss: 1.1769, Train Acc: 59.66%
# Validation Loss: 1.2119, Validation Acc: 58.88%
#
# Epoch 29/100 - Training
# [========================================] 625/625 | Loss: 1.181 | Accuracy: 59.55%
# Epoch 29/100 - Evaluation
# [========================================] 157/157 | Loss: 1.245 | Accuracy: 58.18%
# Train Loss: 1.1810, Train Acc: 59.55%
# Validation Loss: 1.2454, Validation Acc: 58.18%
#
# Epoch 30/100 - Training
# [========================================] 625/625 | Loss: 1.183 | Accuracy: 59.40%
# Epoch 30/100 - Evaluation
# [========================================] 157/157 | Loss: 1.210 | Accuracy: 58.96%
# Train Loss: 1.1826, Train Acc: 59.40%
# Validation Loss: 1.2103, Validation Acc: 58.96%
#
# Epoch 31/100 - Training
# [========================================] 625/625 | Loss: 1.178 | Accuracy: 59.73%
# Epoch 31/100 - Evaluation
# [========================================] 157/157 | Loss: 1.232 | Accuracy: 58.33%
# Train Loss: 1.1781, Train Acc: 59.73%
# Validation Loss: 1.2320, Validation Acc: 58.33%
#
# Epoch 32/100 - Training
# [========================================] 625/625 | Loss: 1.167 | Accuracy: 60.20%
# Epoch 32/100 - Evaluation
# [========================================] 157/157 | Loss: 1.256 | Accuracy: 57.54%
# Train Loss: 1.1668, Train Acc: 60.20%
# Validation Loss: 1.2564, Validation Acc: 57.54%
#
# Epoch 33/100 - Training
# [========================================] 625/625 | Loss: 1.166 | Accuracy: 60.23%
# Epoch 33/100 - Evaluation
# [========================================] 157/157 | Loss: 1.203 | Accuracy: 58.49%
# Train Loss: 1.1661, Train Acc: 60.23%
# Validation Loss: 1.2031, Validation Acc: 58.49%
#
# Epoch 34/100 - Training
# [========================================] 625/625 | Loss: 1.164 | Accuracy: 60.16%
# Epoch 34/100 - Evaluation
# [========================================] 157/157 | Loss: 1.284 | Accuracy: 57.40%
# Train Loss: 1.1641, Train Acc: 60.16%
# Validation Loss: 1.2841, Validation Acc: 57.40%
#
# Epoch 35/100 - Training
# [========================================] 625/625 | Loss: 1.170 | Accuracy: 60.29%
# Epoch 35/100 - Evaluation
# [========================================] 157/157 | Loss: 1.243 | Accuracy: 57.36%
# Train Loss: 1.1704, Train Acc: 60.29%
# Validation Loss: 1.2432, Validation Acc: 57.36%
#
# Epoch 36/100 - Training
# [========================================] 625/625 | Loss: 1.174 | Accuracy: 59.76%
# Epoch 36/100 - Evaluation
# [========================================] 157/157 | Loss: 1.283 | Accuracy: 56.69%
# Train Loss: 1.1738, Train Acc: 59.76%
# Validation Loss: 1.2829, Validation Acc: 56.69%
#
# Epoch 37/100 - Training
# [========================================] 625/625 | Loss: 1.173 | Accuracy: 59.94%
# Epoch 37/100 - Evaluation
# [========================================] 157/157 | Loss: 1.232 | Accuracy: 57.84%
# Train Loss: 1.1730, Train Acc: 59.94%
# Validation Loss: 1.2317, Validation Acc: 57.84%
#
# Epoch 38/100 - Training
# [========================================] 625/625 | Loss: 1.169 | Accuracy: 59.85%
# Epoch 38/100 - Evaluation
# [========================================] 157/157 | Loss: 1.206 | Accuracy: 58.94%
# Train Loss: 1.1694, Train Acc: 59.85%
# Validation Loss: 1.2061, Validation Acc: 58.94%
#
# Epoch 39/100 - Training
# [========================================] 625/625 | Loss: 1.168 | Accuracy: 60.28%
# Epoch 39/100 - Evaluation
# [========================================] 157/157 | Loss: 1.236 | Accuracy: 58.56%
# Train Loss: 1.1683, Train Acc: 60.28%
# Validation Loss: 1.2363, Validation Acc: 58.56%
#
# Epoch 40/100 - Training
# [========================================] 625/625 | Loss: 1.165 | Accuracy: 60.22%
# Epoch 40/100 - Evaluation
# [========================================] 157/157 | Loss: 1.224 | Accuracy: 58.12%
# Train Loss: 1.1654, Train Acc: 60.22%
# Validation Loss: 1.2240, Validation Acc: 58.12%
#
# Epoch 41/100 - Training
# [========================================] 625/625 | Loss: 1.158 | Accuracy: 60.11%
# Epoch 41/100 - Evaluation
# [========================================] 157/157 | Loss: 1.203 | Accuracy: 58.81%
# Train Loss: 1.1575, Train Acc: 60.11%
# Validation Loss: 1.2031, Validation Acc: 58.81%
#
# Epoch 42/100 - Training
# [========================================] 625/625 | Loss: 1.166 | Accuracy: 60.37%
# Epoch 42/100 - Evaluation
# [========================================] 157/157 | Loss: 1.216 | Accuracy: 58.40%
# Train Loss: 1.1661, Train Acc: 60.37%
# Validation Loss: 1.2164, Validation Acc: 58.40%
#
# Epoch 43/100 - Training
# [========================================] 625/625 | Loss: 1.162 | Accuracy: 60.27%
# Epoch 43/100 - Evaluation
# [========================================] 157/157 | Loss: 1.214 | Accuracy: 58.65%
# Train Loss: 1.1625, Train Acc: 60.27%
# Validation Loss: 1.2142, Validation Acc: 58.65%
#
# Epoch 44/100 - Training
# [========================================] 625/625 | Loss: 1.155 | Accuracy: 60.44%
# Epoch 44/100 - Evaluation
# [========================================] 157/157 | Loss: 1.224 | Accuracy: 58.81%
# Train Loss: 1.1545, Train Acc: 60.44%
# Validation Loss: 1.2238, Validation Acc: 58.81%
#
# Epoch 45/100 - Training
# [========================================] 625/625 | Loss: 1.156 | Accuracy: 60.55%
# Epoch 45/100 - Evaluation
# [========================================] 157/157 | Loss: 1.208 | Accuracy: 58.91%
# Train Loss: 1.1563, Train Acc: 60.55%
# Validation Loss: 1.2078, Validation Acc: 58.91%
#
# Epoch 46/100 - Training
# [========================================] 625/625 | Loss: 1.146 | Accuracy: 60.84%
# Epoch 46/100 - Evaluation
# [========================================] 157/157 | Loss: 1.213 | Accuracy: 58.52%
# Train Loss: 1.1461, Train Acc: 60.84%
# Validation Loss: 1.2132, Validation Acc: 58.52%
#
# Epoch 47/100 - Training
# [========================================] 625/625 | Loss: 1.158 | Accuracy: 60.36%
# Epoch 47/100 - Evaluation
# [========================================] 157/157 | Loss: 1.201 | Accuracy: 59.24%
# Train Loss: 1.1582, Train Acc: 60.36%
# Validation Loss: 1.2013, Validation Acc: 59.24%
#
# Epoch 48/100 - Training
# [========================================] 625/625 | Loss: 1.149 | Accuracy: 60.52%
# Epoch 48/100 - Evaluation
# [========================================] 157/157 | Loss: 1.207 | Accuracy: 59.62%
# Train Loss: 1.1487, Train Acc: 60.52%
# Validation Loss: 1.2072, Validation Acc: 59.62%
#
# Epoch 49/100 - Training
# [========================================] 625/625 | Loss: 1.151 | Accuracy: 60.45%
# Epoch 49/100 - Evaluation
# [========================================] 157/157 | Loss: 1.220 | Accuracy: 59.02%
# Train Loss: 1.1513, Train Acc: 60.45%
# Validation Loss: 1.2204, Validation Acc: 59.02%
#
# Epoch 50/100 - Training
# [========================================] 625/625 | Loss: 1.155 | Accuracy: 60.30%
# Epoch 50/100 - Evaluation
# [========================================] 157/157 | Loss: 1.194 | Accuracy: 60.02%
# Train Loss: 1.1555, Train Acc: 60.30%
# Validation Loss: 1.1936, Validation Acc: 60.02%
#
# Epoch 51/100 - Training
# [========================================] 625/625 | Loss: 1.151 | Accuracy: 60.87%
# Epoch 51/100 - Evaluation
# [========================================] 157/157 | Loss: 1.206 | Accuracy: 58.76%
# Train Loss: 1.1505, Train Acc: 60.87%
# Validation Loss: 1.2061, Validation Acc: 58.76%
#
# Epoch 52/100 - Training
# [========================================] 625/625 | Loss: 1.148 | Accuracy: 60.60%
# Epoch 52/100 - Evaluation
# [========================================] 157/157 | Loss: 1.242 | Accuracy: 58.35%
# Train Loss: 1.1485, Train Acc: 60.60%
# Validation Loss: 1.2421, Validation Acc: 58.35%
#
# Epoch 53/100 - Training
# [========================================] 625/625 | Loss: 1.148 | Accuracy: 60.63%
# Epoch 53/100 - Evaluation
# [========================================] 157/157 | Loss: 1.183 | Accuracy: 59.93%
# Train Loss: 1.1482, Train Acc: 60.63%
# Validation Loss: 1.1829, Validation Acc: 59.93%
#
# Epoch 54/100 - Training
# [========================================] 625/625 | Loss: 1.147 | Accuracy: 60.76%
# Epoch 54/100 - Evaluation
# [========================================] 157/157 | Loss: 1.207 | Accuracy: 59.52%
# Train Loss: 1.1474, Train Acc: 60.76%
# Validation Loss: 1.2067, Validation Acc: 59.52%
#
# Epoch 55/100 - Training
# [========================================] 625/625 | Loss: 1.145 | Accuracy: 60.72%
# Epoch 55/100 - Evaluation
# [========================================] 157/157 | Loss: 1.190 | Accuracy: 60.02%
# Train Loss: 1.1450, Train Acc: 60.72%
# Validation Loss: 1.1897, Validation Acc: 60.02%
#
# Epoch 56/100 - Training
# [========================================] 625/625 | Loss: 1.145 | Accuracy: 60.81%
# Epoch 56/100 - Evaluation
# [========================================] 157/157 | Loss: 1.227 | Accuracy: 58.60%
# Train Loss: 1.1451, Train Acc: 60.81%
# Validation Loss: 1.2267, Validation Acc: 58.60%
#
# Epoch 57/100 - Training
# [========================================] 625/625 | Loss: 1.150 | Accuracy: 60.62%
# Epoch 57/100 - Evaluation
# [========================================] 157/157 | Loss: 1.214 | Accuracy: 58.51%
# Train Loss: 1.1501, Train Acc: 60.62%
# Validation Loss: 1.2139, Validation Acc: 58.51%
#
# Epoch 58/100 - Training
# [========================================] 625/625 | Loss: 1.149 | Accuracy: 60.73%
# Epoch 58/100 - Evaluation
# [========================================] 157/157 | Loss: 1.197 | Accuracy: 59.27%
# Train Loss: 1.1489, Train Acc: 60.73%
# Validation Loss: 1.1972, Validation Acc: 59.27%
#
# Epoch 59/100 - Training
# [========================================] 625/625 | Loss: 1.151 | Accuracy: 60.73%
# Epoch 59/100 - Evaluation
# [========================================] 157/157 | Loss: 1.214 | Accuracy: 58.86%
# Train Loss: 1.1512, Train Acc: 60.73%
# Validation Loss: 1.2142, Validation Acc: 58.86%
#
# Epoch 60/100 - Training
# [========================================] 625/625 | Loss: 1.145 | Accuracy: 60.84%
# Epoch 60/100 - Evaluation
# [========================================] 157/157 | Loss: 1.211 | Accuracy: 58.86%
# Train Loss: 1.1452, Train Acc: 60.84%
# Validation Loss: 1.2107, Validation Acc: 58.86%
#
# Epoch 61/100 - Training
# [========================================] 625/625 | Loss: 1.144 | Accuracy: 60.79%
# Epoch 61/100 - Evaluation
# [========================================] 157/157 | Loss: 1.198 | Accuracy: 59.43%
# Train Loss: 1.1438, Train Acc: 60.79%
# Validation Loss: 1.1984, Validation Acc: 59.43%
#
# Epoch 62/100 - Training
# [========================================] 625/625 | Loss: 1.133 | Accuracy: 60.98%
# Epoch 62/100 - Evaluation
# [========================================] 157/157 | Loss: 1.224 | Accuracy: 59.61%
# Train Loss: 1.1334, Train Acc: 60.98%
# Validation Loss: 1.2238, Validation Acc: 59.61%
#
# Epoch 63/100 - Training
# [========================================] 625/625 | Loss: 1.141 | Accuracy: 60.78%
# Epoch 63/100 - Evaluation
# [========================================] 157/157 | Loss: 1.178 | Accuracy: 60.34%
# Train Loss: 1.1409, Train Acc: 60.78%
# Validation Loss: 1.1779, Validation Acc: 60.34%
#
# Epoch 64/100 - Training
# [========================================] 625/625 | Loss: 1.145 | Accuracy: 60.88%
# Epoch 64/100 - Evaluation
# [========================================] 157/157 | Loss: 1.193 | Accuracy: 60.62%
# Train Loss: 1.1448, Train Acc: 60.88%
# Validation Loss: 1.1934, Validation Acc: 60.62%
#
# Epoch 65/100 - Training
# [========================================] 625/625 | Loss: 1.137 | Accuracy: 61.21%
# Epoch 65/100 - Evaluation
# [========================================] 157/157 | Loss: 1.164 | Accuracy: 60.66%
# Train Loss: 1.1374, Train Acc: 61.21%
# Validation Loss: 1.1640, Validation Acc: 60.66%
#
# Epoch 66/100 - Training
# [========================================] 625/625 | Loss: 1.142 | Accuracy: 60.71%
# Epoch 66/100 - Evaluation
# [========================================] 157/157 | Loss: 1.221 | Accuracy: 58.99%
# Train Loss: 1.1424, Train Acc: 60.71%
# Validation Loss: 1.2205, Validation Acc: 58.99%
#
# Epoch 67/100 - Training
# [========================================] 625/625 | Loss: 1.149 | Accuracy: 60.59%
# Epoch 67/100 - Evaluation
# [========================================] 157/157 | Loss: 1.181 | Accuracy: 60.32%
# Train Loss: 1.1487, Train Acc: 60.59%
# Validation Loss: 1.1813, Validation Acc: 60.32%
#
# Epoch 68/100 - Training
# [========================================] 625/625 | Loss: 1.136 | Accuracy: 61.28%
# Epoch 68/100 - Evaluation
# [========================================] 157/157 | Loss: 1.189 | Accuracy: 60.38%
# Train Loss: 1.1357, Train Acc: 61.28%
# Validation Loss: 1.1893, Validation Acc: 60.38%
#
# Epoch 69/100 - Training
# [========================================] 625/625 | Loss: 1.143 | Accuracy: 60.91%
# Epoch 69/100 - Evaluation
# [========================================] 157/157 | Loss: 1.169 | Accuracy: 60.41%
# Train Loss: 1.1426, Train Acc: 60.91%
# Validation Loss: 1.1692, Validation Acc: 60.41%
#
# Epoch 70/100 - Training
# [========================================] 625/625 | Loss: 1.141 | Accuracy: 61.10%
# Epoch 70/100 - Evaluation
# [========================================] 157/157 | Loss: 1.171 | Accuracy: 60.83%
# Train Loss: 1.1407, Train Acc: 61.10%
# Validation Loss: 1.1708, Validation Acc: 60.83%
#
# Epoch 71/100 - Training
# [========================================] 625/625 | Loss: 1.136 | Accuracy: 60.88%
# Epoch 71/100 - Evaluation
# [========================================] 157/157 | Loss: 1.187 | Accuracy: 60.52%
# Train Loss: 1.1362, Train Acc: 60.88%
# Validation Loss: 1.1871, Validation Acc: 60.52%
#
# Epoch 72/100 - Training
# [========================================] 625/625 | Loss: 1.136 | Accuracy: 60.86%
# Epoch 72/100 - Evaluation
# [========================================] 157/157 | Loss: 1.191 | Accuracy: 59.94%
# Train Loss: 1.1364, Train Acc: 60.86%
# Validation Loss: 1.1912, Validation Acc: 59.94%
#
# Epoch 73/100 - Training
# [========================================] 625/625 | Loss: 1.134 | Accuracy: 61.18%
# Epoch 73/100 - Evaluation
# [========================================] 157/157 | Loss: 1.210 | Accuracy: 58.96%
# Train Loss: 1.1335, Train Acc: 61.18%
# Validation Loss: 1.2098, Validation Acc: 58.96%
#
# Epoch 74/100 - Training
# [========================================] 625/625 | Loss: 1.131 | Accuracy: 61.43%
# Epoch 74/100 - Evaluation
# [========================================] 157/157 | Loss: 1.184 | Accuracy: 59.74%
# Train Loss: 1.1309, Train Acc: 61.43%
# Validation Loss: 1.1844, Validation Acc: 59.74%
#
# Epoch 75/100 - Training
# [========================================] 625/625 | Loss: 1.134 | Accuracy: 61.46%
# Epoch 75/100 - Evaluation
# [========================================] 157/157 | Loss: 1.220 | Accuracy: 58.97%
# Train Loss: 1.1338, Train Acc: 61.46%
# Validation Loss: 1.2202, Validation Acc: 58.97%
#
# Epoch 76/100 - Training
# [========================================] 625/625 | Loss: 1.129 | Accuracy: 61.20%
# Epoch 76/100 - Evaluation
# [========================================] 157/157 | Loss: 1.186 | Accuracy: 60.37%
# Train Loss: 1.1295, Train Acc: 61.20%
# Validation Loss: 1.1855, Validation Acc: 60.37%
#
# Epoch 77/100 - Training
# [========================================] 625/625 | Loss: 1.149 | Accuracy: 60.54%
# Epoch 77/100 - Evaluation
# [========================================] 157/157 | Loss: 1.197 | Accuracy: 58.85%
# Train Loss: 1.1487, Train Acc: 60.54%
# Validation Loss: 1.1969, Validation Acc: 58.85%
#
# Epoch 78/100 - Training
# [========================================] 625/625 | Loss: 1.133 | Accuracy: 61.27%
# Epoch 78/100 - Evaluation
# [========================================] 157/157 | Loss: 1.209 | Accuracy: 59.53%
# Train Loss: 1.1332, Train Acc: 61.27%
# Validation Loss: 1.2088, Validation Acc: 59.53%
#
# Epoch 79/100 - Training
# [========================================] 625/625 | Loss: 1.130 | Accuracy: 61.42%
# Epoch 79/100 - Evaluation
# [========================================] 157/157 | Loss: 1.180 | Accuracy: 60.18%
# Train Loss: 1.1300, Train Acc: 61.42%
# Validation Loss: 1.1804, Validation Acc: 60.18%
#
# Epoch 80/100 - Training
# [========================================] 625/625 | Loss: 1.136 | Accuracy: 61.12%
# Epoch 80/100 - Evaluation
# [========================================] 157/157 | Loss: 1.197 | Accuracy: 59.77%
# Train Loss: 1.1359, Train Acc: 61.12%
# Validation Loss: 1.1967, Validation Acc: 59.77%
#
# Epoch 81/100 - Training
# [========================================] 625/625 | Loss: 1.139 | Accuracy: 61.10%
# Epoch 81/100 - Evaluation
# [========================================] 157/157 | Loss: 1.248 | Accuracy: 57.88%
# Train Loss: 1.1395, Train Acc: 61.10%
# Validation Loss: 1.2479, Validation Acc: 57.88%
#
# Epoch 82/100 - Training
# [========================================] 625/625 | Loss: 1.132 | Accuracy: 61.28%
# Epoch 82/100 - Evaluation
# [========================================] 157/157 | Loss: 1.181 | Accuracy: 59.90%
# Train Loss: 1.1322, Train Acc: 61.28%
# Validation Loss: 1.1815, Validation Acc: 59.90%
#
# Epoch 83/100 - Training
# [========================================] 625/625 | Loss: 1.133 | Accuracy: 61.38%
# Epoch 83/100 - Evaluation
# [========================================] 157/157 | Loss: 1.203 | Accuracy: 59.72%
# Train Loss: 1.1334, Train Acc: 61.38%
# Validation Loss: 1.2029, Validation Acc: 59.72%
#
# Epoch 84/100 - Training
# [========================================] 625/625 | Loss: 1.130 | Accuracy: 61.42%
# Epoch 84/100 - Evaluation
# [========================================] 157/157 | Loss: 1.205 | Accuracy: 60.08%
# Train Loss: 1.1303, Train Acc: 61.42%
# Validation Loss: 1.2047, Validation Acc: 60.08%
#
# Epoch 85/100 - Training
# [========================================] 625/625 | Loss: 1.142 | Accuracy: 61.04%
# Epoch 85/100 - Evaluation
# [========================================] 157/157 | Loss: 1.218 | Accuracy: 58.23%Early stopping at epoch 85 with best validation loss: 1.1640
#
# Training complete in 72m 34s.

# %%
plot_result(result)

# %%
results = evaluate_test_set(
    model=shallow_mlp,
    testloader=testloader,
    criterion=criterion,
    model_path="model_20250504_073512_64.pt",
    device=device
)
# Out:
# Test Loss: 1.1377, Test Accuracy: 60.98%

# %%
# Confusion matrix
cm = confusion_matrix(results[2], results[3])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=full_dataset.classes)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - Test Set")
plt.show()

# %%
lr = 0.0001

shallow_kan = KAN([input_dim * input_dim * 3, classes], grid_size=10)

total_params_kan, trainable_params_kan = count_parameters(shallow_kan)
print(f"Total parameters: {total_params_kan}")
print(f"Trainable parameters: {trainable_params_kan}")

optimizer = optim.AdamW(shallow_kan.parameters(), lr=lr, weight_decay=0.01)
criterion = nn.CrossEntropyLoss()
# Out:
# Total parameters: 460800
# Trainable parameters: 460800

# %%
result_kan = train_model(shallow_kan, trainloader, valloader, device,
                                  optimizer, criterion,
                                  epochs, input_dim, model_name="KAN")
# Out:
# Epoch 1/100 - Training
# [========================================] 625/625 | Loss: 2.019 | Accuracy: 28.14%
# Epoch 1/100 - Evaluation
# [========================================] 157/157 | Loss: 1.973 | Accuracy: 30.74%
# Train Loss: 2.0188, Train Acc: 28.14%
# Validation Loss: 1.9728, Validation Acc: 30.74%
#
# Epoch 2/100 - Training
# [========================================] 625/625 | Loss: 1.928 | Accuracy: 32.08%
# Epoch 2/100 - Evaluation
# [========================================] 157/157 | Loss: 1.928 | Accuracy: 32.26%
# Train Loss: 1.9277, Train Acc: 32.08%
# Validation Loss: 1.9284, Validation Acc: 32.26%
#
# Epoch 3/100 - Training
# [========================================] 625/625 | Loss: 1.899 | Accuracy: 33.47%
# Epoch 3/100 - Evaluation
# [========================================] 157/157 | Loss: 1.909 | Accuracy: 33.36%
# Train Loss: 1.8994, Train Acc: 33.47%
# Validation Loss: 1.9088, Validation Acc: 33.36%
#
# Epoch 4/100 - Training
# [========================================] 625/625 | Loss: 1.877 | Accuracy: 34.45%
# Epoch 4/100 - Evaluation
# [========================================] 157/157 | Loss: 1.898 | Accuracy: 33.50%
# Train Loss: 1.8765, Train Acc: 34.45%
# Validation Loss: 1.8980, Validation Acc: 33.50%
#
# Epoch 5/100 - Training
# [========================================] 625/625 | Loss: 1.864 | Accuracy: 34.61%
# Epoch 5/100 - Evaluation
# [========================================] 157/157 | Loss: 1.879 | Accuracy: 34.66%
# Train Loss: 1.8637, Train Acc: 34.61%
# Validation Loss: 1.8794, Validation Acc: 34.66%
#
# Epoch 6/100 - Training
# [========================================] 625/625 | Loss: 1.854 | Accuracy: 34.98%
# Epoch 6/100 - Evaluation
# [========================================] 157/157 | Loss: 1.864 | Accuracy: 35.08%
# Train Loss: 1.8540, Train Acc: 34.98%
# Validation Loss: 1.8641, Validation Acc: 35.08%
#
# Epoch 7/100 - Training
# [========================================] 625/625 | Loss: 1.845 | Accuracy: 35.49%
# Epoch 7/100 - Evaluation
# [========================================] 157/157 | Loss: 1.876 | Accuracy: 34.68%
# Train Loss: 1.8449, Train Acc: 35.49%
# Validation Loss: 1.8759, Validation Acc: 34.68%
#
# Epoch 8/100 - Training
# [========================================] 625/625 | Loss: 1.839 | Accuracy: 35.74%
# Epoch 8/100 - Evaluation
# [========================================] 157/157 | Loss: 1.871 | Accuracy: 35.28%
# Train Loss: 1.8390, Train Acc: 35.74%
# Validation Loss: 1.8707, Validation Acc: 35.28%
#
# Epoch 9/100 - Training
# [========================================] 625/625 | Loss: 1.837 | Accuracy: 35.92%
# Epoch 9/100 - Evaluation
# [========================================] 157/157 | Loss: 1.863 | Accuracy: 34.85%
# Train Loss: 1.8367, Train Acc: 35.92%
# Validation Loss: 1.8627, Validation Acc: 34.85%
#
# Epoch 10/100 - Training
# [========================================] 625/625 | Loss: 1.829 | Accuracy: 36.12%
# Epoch 10/100 - Evaluation
# [========================================] 157/157 | Loss: 1.850 | Accuracy: 35.66%
# Train Loss: 1.8286, Train Acc: 36.12%
# Validation Loss: 1.8501, Validation Acc: 35.66%
#
# Epoch 11/100 - Training
# [========================================] 625/625 | Loss: 1.825 | Accuracy: 36.42%
# Epoch 11/100 - Evaluation
# [========================================] 157/157 | Loss: 1.850 | Accuracy: 35.31%
# Train Loss: 1.8250, Train Acc: 36.42%
# Validation Loss: 1.8505, Validation Acc: 35.31%
#
# Epoch 12/100 - Training
# [========================================] 625/625 | Loss: 1.821 | Accuracy: 36.19%
# Epoch 12/100 - Evaluation
# [========================================] 157/157 | Loss: 1.847 | Accuracy: 35.43%
# Train Loss: 1.8205, Train Acc: 36.19%
# Validation Loss: 1.8470, Validation Acc: 35.43%
#
# Epoch 13/100 - Training
# [========================================] 625/625 | Loss: 1.818 | Accuracy: 36.43%
# Epoch 13/100 - Evaluation
# [========================================] 157/157 | Loss: 1.839 | Accuracy: 36.28%
# Train Loss: 1.8184, Train Acc: 36.43%
# Validation Loss: 1.8390, Validation Acc: 36.28%
#
# Epoch 14/100 - Training
# [========================================] 625/625 | Loss: 1.817 | Accuracy: 36.58%
# Epoch 14/100 - Evaluation
# [========================================] 157/157 | Loss: 1.848 | Accuracy: 35.25%
# Train Loss: 1.8168, Train Acc: 36.58%
# Validation Loss: 1.8483, Validation Acc: 35.25%
#
# Epoch 15/100 - Training
# [========================================] 625/625 | Loss: 1.812 | Accuracy: 36.83%
# Epoch 15/100 - Evaluation
# [========================================] 157/157 | Loss: 1.844 | Accuracy: 35.97%
# Train Loss: 1.8117, Train Acc: 36.83%
# Validation Loss: 1.8441, Validation Acc: 35.97%
#
# Epoch 16/100 - Training
# [========================================] 625/625 | Loss: 1.811 | Accuracy: 37.08%
# Epoch 16/100 - Evaluation
# [========================================] 157/157 | Loss: 1.846 | Accuracy: 35.28%
# Train Loss: 1.8109, Train Acc: 37.08%
# Validation Loss: 1.8456, Validation Acc: 35.28%
#
# Epoch 17/100 - Training
# [========================================] 625/625 | Loss: 1.806 | Accuracy: 37.11%
# Epoch 17/100 - Evaluation
# [========================================] 157/157 | Loss: 1.828 | Accuracy: 36.17%
# Train Loss: 1.8061, Train Acc: 37.11%
# Validation Loss: 1.8278, Validation Acc: 36.17%
#
# Epoch 18/100 - Training
# [========================================] 625/625 | Loss: 1.807 | Accuracy: 37.09%
# Epoch 18/100 - Evaluation
# [========================================] 157/157 | Loss: 1.835 | Accuracy: 36.32%
# Train Loss: 1.8069, Train Acc: 37.09%
# Validation Loss: 1.8352, Validation Acc: 36.32%
#
# Epoch 19/100 - Training
# [========================================] 625/625 | Loss: 1.808 | Accuracy: 37.02%
# Epoch 19/100 - Evaluation
# [========================================] 157/157 | Loss: 1.842 | Accuracy: 36.17%
# Train Loss: 1.8082, Train Acc: 37.02%
# Validation Loss: 1.8417, Validation Acc: 36.17%
#
# Epoch 20/100 - Training
# [========================================] 625/625 | Loss: 1.802 | Accuracy: 37.35%
# Epoch 20/100 - Evaluation
# [========================================] 157/157 | Loss: 1.843 | Accuracy: 36.34%
# Train Loss: 1.8025, Train Acc: 37.35%
# Validation Loss: 1.8427, Validation Acc: 36.34%
#
# Epoch 21/100 - Training
# [========================================] 625/625 | Loss: 1.802 | Accuracy: 37.43%
# Epoch 21/100 - Evaluation
# [========================================] 157/157 | Loss: 1.827 | Accuracy: 36.64%
# Train Loss: 1.8023, Train Acc: 37.43%
# Validation Loss: 1.8274, Validation Acc: 36.64%
#
# Epoch 22/100 - Training
# [========================================] 625/625 | Loss: 1.799 | Accuracy: 37.45%
# Epoch 22/100 - Evaluation
# [========================================] 157/157 | Loss: 1.834 | Accuracy: 35.94%
# Train Loss: 1.7985, Train Acc: 37.45%
# Validation Loss: 1.8336, Validation Acc: 35.94%
#
# Epoch 23/100 - Training
# [========================================] 625/625 | Loss: 1.799 | Accuracy: 37.41%
# Epoch 23/100 - Evaluation
# [========================================] 157/157 | Loss: 1.823 | Accuracy: 36.52%
# Train Loss: 1.7989, Train Acc: 37.41%
# Validation Loss: 1.8232, Validation Acc: 36.52%
#
# Epoch 24/100 - Training
# [========================================] 625/625 | Loss: 1.804 | Accuracy: 37.31%
# Epoch 24/100 - Evaluation
# [========================================] 157/157 | Loss: 1.825 | Accuracy: 36.78%
# Train Loss: 1.8041, Train Acc: 37.31%
# Validation Loss: 1.8245, Validation Acc: 36.78%
#
# Epoch 25/100 - Training
# [========================================] 625/625 | Loss: 1.797 | Accuracy: 37.59%
# Epoch 25/100 - Evaluation
# [========================================] 157/157 | Loss: 1.825 | Accuracy: 36.83%
# Train Loss: 1.7967, Train Acc: 37.59%
# Validation Loss: 1.8247, Validation Acc: 36.83%
#
# Epoch 26/100 - Training
# [========================================] 625/625 | Loss: 1.794 | Accuracy: 37.52%
# Epoch 26/100 - Evaluation
# [========================================] 157/157 | Loss: 1.833 | Accuracy: 35.87%
# Train Loss: 1.7939, Train Acc: 37.52%
# Validation Loss: 1.8330, Validation Acc: 35.87%
#
# Epoch 27/100 - Training
# [========================================] 625/625 | Loss: 1.795 | Accuracy: 37.53%
# Epoch 27/100 - Evaluation
# [========================================] 157/157 | Loss: 1.834 | Accuracy: 36.34%
# Train Loss: 1.7954, Train Acc: 37.53%
# Validation Loss: 1.8344, Validation Acc: 36.34%
#
# Epoch 28/100 - Training
# [========================================] 625/625 | Loss: 1.791 | Accuracy: 37.71%
# Epoch 28/100 - Evaluation
# [========================================] 157/157 | Loss: 1.836 | Accuracy: 36.01%
# Train Loss: 1.7915, Train Acc: 37.71%
# Validation Loss: 1.8360, Validation Acc: 36.01%
#
# Epoch 29/100 - Training
# [========================================] 625/625 | Loss: 1.792 | Accuracy: 37.88%
# Epoch 29/100 - Evaluation
# [========================================] 157/157 | Loss: 1.821 | Accuracy: 37.36%
# Train Loss: 1.7921, Train Acc: 37.88%
# Validation Loss: 1.8213, Validation Acc: 37.36%
#
# Epoch 30/100 - Training
# [========================================] 625/625 | Loss: 1.794 | Accuracy: 37.59%
# Epoch 30/100 - Evaluation
# [========================================] 157/157 | Loss: 1.824 | Accuracy: 36.88%
# Train Loss: 1.7939, Train Acc: 37.59%
# Validation Loss: 1.8241, Validation Acc: 36.88%
#
# Epoch 31/100 - Training
# [========================================] 625/625 | Loss: 1.790 | Accuracy: 37.66%
# Epoch 31/100 - Evaluation
# [========================================] 157/157 | Loss: 1.823 | Accuracy: 36.29%
# Train Loss: 1.7900, Train Acc: 37.66%
# Validation Loss: 1.8232, Validation Acc: 36.29%
#
# Epoch 32/100 - Training
# [========================================] 625/625 | Loss: 1.785 | Accuracy: 38.22%
# Epoch 32/100 - Evaluation
# [========================================] 157/157 | Loss: 1.826 | Accuracy: 36.97%
# Train Loss: 1.7847, Train Acc: 38.22%
# Validation Loss: 1.8264, Validation Acc: 36.97%
#
# Epoch 33/100 - Training
# [========================================] 625/625 | Loss: 1.789 | Accuracy: 38.03%
# Epoch 33/100 - Evaluation
# [========================================] 157/157 | Loss: 1.827 | Accuracy: 36.12%
# Train Loss: 1.7889, Train Acc: 38.03%
# Validation Loss: 1.8274, Validation Acc: 36.12%
#
# Epoch 34/100 - Training
# [========================================] 625/625 | Loss: 1.788 | Accuracy: 37.61%
# Epoch 34/100 - Evaluation
# [========================================] 157/157 | Loss: 1.831 | Accuracy: 35.94%
# Train Loss: 1.7882, Train Acc: 37.61%
# Validation Loss: 1.8308, Validation Acc: 35.94%
#
# Epoch 35/100 - Training
# [========================================] 625/625 | Loss: 1.788 | Accuracy: 37.82%
# Epoch 35/100 - Evaluation
# [========================================] 157/157 | Loss: 1.836 | Accuracy: 36.45%
# Train Loss: 1.7881, Train Acc: 37.82%
# Validation Loss: 1.8355, Validation Acc: 36.45%
#
# Epoch 36/100 - Training
# [========================================] 625/625 | Loss: 1.789 | Accuracy: 37.96%
# Epoch 36/100 - Evaluation
# [========================================] 157/157 | Loss: 1.826 | Accuracy: 37.00%
# Train Loss: 1.7891, Train Acc: 37.96%
# Validation Loss: 1.8262, Validation Acc: 37.00%
#
# Epoch 37/100 - Training
# [========================================] 625/625 | Loss: 1.784 | Accuracy: 37.78%
# Epoch 37/100 - Evaluation
# [========================================] 157/157 | Loss: 1.826 | Accuracy: 37.12%
# Train Loss: 1.7840, Train Acc: 37.78%
# Validation Loss: 1.8258, Validation Acc: 37.12%
#
# Epoch 38/100 - Training
# [========================================] 625/625 | Loss: 1.786 | Accuracy: 37.86%
# Epoch 38/100 - Evaluation
# [========================================] 157/157 | Loss: 1.833 | Accuracy: 36.51%
# Train Loss: 1.7857, Train Acc: 37.86%
# Validation Loss: 1.8326, Validation Acc: 36.51%
#
# Epoch 39/100 - Training
# [========================================] 625/625 | Loss: 1.787 | Accuracy: 38.00%
# Epoch 39/100 - Evaluation
# [========================================] 157/157 | Loss: 1.825 | Accuracy: 36.78%
# Train Loss: 1.7872, Train Acc: 38.00%
# Validation Loss: 1.8249, Validation Acc: 36.78%
#
# Epoch 40/100 - Training
# [========================================] 625/625 | Loss: 1.781 | Accuracy: 38.13%
# Epoch 40/100 - Evaluation
# [========================================] 157/157 | Loss: 1.820 | Accuracy: 36.81%
# Train Loss: 1.7813, Train Acc: 38.13%
# Validation Loss: 1.8198, Validation Acc: 36.81%
#
# Epoch 41/100 - Training
# [========================================] 625/625 | Loss: 1.783 | Accuracy: 37.80%
# Epoch 41/100 - Evaluation
# [========================================] 157/157 | Loss: 1.831 | Accuracy: 36.92%
# Train Loss: 1.7832, Train Acc: 37.80%
# Validation Loss: 1.8315, Validation Acc: 36.92%
#
# Epoch 42/100 - Training
# [========================================] 625/625 | Loss: 1.780 | Accuracy: 38.31%
# Epoch 42/100 - Evaluation
# [========================================] 157/157 | Loss: 1.826 | Accuracy: 36.36%
# Train Loss: 1.7800, Train Acc: 38.31%
# Validation Loss: 1.8258, Validation Acc: 36.36%
#
# Epoch 43/100 - Training
# [========================================] 625/625 | Loss: 1.781 | Accuracy: 38.23%
# Epoch 43/100 - Evaluation
# [========================================] 157/157 | Loss: 1.826 | Accuracy: 36.13%
# Train Loss: 1.7814, Train Acc: 38.23%
# Validation Loss: 1.8256, Validation Acc: 36.13%
#
# Epoch 44/100 - Training
# [========================================] 625/625 | Loss: 1.782 | Accuracy: 38.29%
# Epoch 44/100 - Evaluation
# [========================================] 157/157 | Loss: 1.830 | Accuracy: 36.27%
# Train Loss: 1.7816, Train Acc: 38.29%
# Validation Loss: 1.8304, Validation Acc: 36.27%
#
# Epoch 45/100 - Training
# [========================================] 625/625 | Loss: 1.785 | Accuracy: 38.02%
# Epoch 45/100 - Evaluation
# [========================================] 157/157 | Loss: 1.819 | Accuracy: 36.55%
# Train Loss: 1.7852, Train Acc: 38.02%
# Validation Loss: 1.8189, Validation Acc: 36.55%
#
# Epoch 46/100 - Training
# [========================================] 625/625 | Loss: 1.781 | Accuracy: 38.29%
# Epoch 46/100 - Evaluation
# [========================================] 157/157 | Loss: 1.832 | Accuracy: 36.70%
# Train Loss: 1.7809, Train Acc: 38.29%
# Validation Loss: 1.8322, Validation Acc: 36.70%
#
# Epoch 47/100 - Training
# [========================================] 625/625 | Loss: 1.782 | Accuracy: 38.20%
# Epoch 47/100 - Evaluation
# [========================================] 157/157 | Loss: 1.822 | Accuracy: 36.56%
# Train Loss: 1.7821, Train Acc: 38.20%
# Validation Loss: 1.8217, Validation Acc: 36.56%
#
# Epoch 48/100 - Training
# [========================================] 625/625 | Loss: 1.783 | Accuracy: 38.21%
# Epoch 48/100 - Evaluation
# [========================================] 157/157 | Loss: 1.824 | Accuracy: 36.46%
# Train Loss: 1.7826, Train Acc: 38.21%
# Validation Loss: 1.8242, Validation Acc: 36.46%
#
# Epoch 49/100 - Training
# [========================================] 625/625 | Loss: 1.780 | Accuracy: 38.33%
# Epoch 49/100 - Evaluation
# [========================================] 157/157 | Loss: 1.820 | Accuracy: 37.34%
# Train Loss: 1.7801, Train Acc: 38.33%
# Validation Loss: 1.8198, Validation Acc: 37.34%
#
# Epoch 50/100 - Training
# [========================================] 625/625 | Loss: 1.778 | Accuracy: 38.24%
# Epoch 50/100 - Evaluation
# [========================================] 157/157 | Loss: 1.819 | Accuracy: 36.49%
# Train Loss: 1.7775, Train Acc: 38.24%
# Validation Loss: 1.8190, Validation Acc: 36.49%
#
# Epoch 51/100 - Training
# [========================================] 625/625 | Loss: 1.778 | Accuracy: 38.15%
# Epoch 51/100 - Evaluation
# [========================================] 157/157 | Loss: 1.819 | Accuracy: 37.23%
# Train Loss: 1.7782, Train Acc: 38.15%
# Validation Loss: 1.8187, Validation Acc: 37.23%
#
# Epoch 52/100 - Training
# [========================================] 625/625 | Loss: 1.778 | Accuracy: 38.23%
# Epoch 52/100 - Evaluation
# [========================================] 157/157 | Loss: 1.816 | Accuracy: 37.04%
# Train Loss: 1.7783, Train Acc: 38.23%
# Validation Loss: 1.8162, Validation Acc: 37.04%
#
# Epoch 53/100 - Training
# [========================================] 625/625 | Loss: 1.779 | Accuracy: 37.95%
# Epoch 53/100 - Evaluation
# [========================================] 157/157 | Loss: 1.821 | Accuracy: 36.85%
# Train Loss: 1.7792, Train Acc: 37.95%
# Validation Loss: 1.8208, Validation Acc: 36.85%
#
# Epoch 54/100 - Training
# [========================================] 625/625 | Loss: 1.777 | Accuracy: 38.42%
# Epoch 54/100 - Evaluation
# [========================================] 157/157 | Loss: 1.822 | Accuracy: 36.81%
# Train Loss: 1.7767, Train Acc: 38.42%
# Validation Loss: 1.8219, Validation Acc: 36.81%
#
# Epoch 55/100 - Training
# [========================================] 625/625 | Loss: 1.778 | Accuracy: 38.57%
# Epoch 55/100 - Evaluation
# [========================================] 157/157 | Loss: 1.818 | Accuracy: 36.85%
# Train Loss: 1.7779, Train Acc: 38.57%
# Validation Loss: 1.8176, Validation Acc: 36.85%
#
# Epoch 56/100 - Training
# [========================================] 625/625 | Loss: 1.777 | Accuracy: 38.19%
# Epoch 56/100 - Evaluation
# [========================================] 157/157 | Loss: 1.818 | Accuracy: 36.86%
# Train Loss: 1.7767, Train Acc: 38.19%
# Validation Loss: 1.8185, Validation Acc: 36.86%
#
# Epoch 57/100 - Training
# [========================================] 625/625 | Loss: 1.774 | Accuracy: 38.36%
# Epoch 57/100 - Evaluation
# [========================================] 157/157 | Loss: 1.819 | Accuracy: 37.50%
# Train Loss: 1.7736, Train Acc: 38.36%
# Validation Loss: 1.8193, Validation Acc: 37.50%
#
# Epoch 58/100 - Training
# [========================================] 625/625 | Loss: 1.780 | Accuracy: 38.06%
# Epoch 58/100 - Evaluation
# [========================================] 157/157 | Loss: 1.825 | Accuracy: 36.60%
# Train Loss: 1.7797, Train Acc: 38.06%
# Validation Loss: 1.8254, Validation Acc: 36.60%
#
# Epoch 59/100 - Training
# [========================================] 625/625 | Loss: 1.775 | Accuracy: 38.32%
# Epoch 59/100 - Evaluation
# [========================================] 157/157 | Loss: 1.815 | Accuracy: 37.29%
# Train Loss: 1.7752, Train Acc: 38.32%
# Validation Loss: 1.8154, Validation Acc: 37.29%
#
# Epoch 60/100 - Training
# [========================================] 625/625 | Loss: 1.777 | Accuracy: 38.14%
# Epoch 60/100 - Evaluation
# [========================================] 157/157 | Loss: 1.807 | Accuracy: 37.05%
# Train Loss: 1.7772, Train Acc: 38.14%
# Validation Loss: 1.8074, Validation Acc: 37.05%
#
# Epoch 61/100 - Training
# [========================================] 625/625 | Loss: 1.776 | Accuracy: 38.45%
# Epoch 61/100 - Evaluation
# [========================================] 157/157 | Loss: 1.816 | Accuracy: 37.57%
# Train Loss: 1.7757, Train Acc: 38.45%
# Validation Loss: 1.8165, Validation Acc: 37.57%
#
# Epoch 62/100 - Training
# [========================================] 625/625 | Loss: 1.777 | Accuracy: 38.10%
# Epoch 62/100 - Evaluation
# [========================================] 157/157 | Loss: 1.813 | Accuracy: 37.25%
# Train Loss: 1.7772, Train Acc: 38.10%
# Validation Loss: 1.8130, Validation Acc: 37.25%
#
# Epoch 63/100 - Training
# [========================================] 625/625 | Loss: 1.772 | Accuracy: 38.53%
# Epoch 63/100 - Evaluation
# [========================================] 157/157 | Loss: 1.814 | Accuracy: 37.04%
# Train Loss: 1.7723, Train Acc: 38.53%
# Validation Loss: 1.8144, Validation Acc: 37.04%
#
# Epoch 64/100 - Training
# [========================================] 625/625 | Loss: 1.775 | Accuracy: 38.41%
# Epoch 64/100 - Evaluation
# [========================================] 157/157 | Loss: 1.819 | Accuracy: 37.08%
# Train Loss: 1.7747, Train Acc: 38.41%
# Validation Loss: 1.8186, Validation Acc: 37.08%
#
# Epoch 65/100 - Training
# [========================================] 625/625 | Loss: 1.775 | Accuracy: 38.41%
# Epoch 65/100 - Evaluation
# [========================================] 157/157 | Loss: 1.824 | Accuracy: 37.07%
# Train Loss: 1.7747, Train Acc: 38.41%
# Validation Loss: 1.8242, Validation Acc: 37.07%
#
# Epoch 66/100 - Training
# [========================================] 625/625 | Loss: 1.773 | Accuracy: 38.70%
# Epoch 66/100 - Evaluation
# [========================================] 157/157 | Loss: 1.817 | Accuracy: 37.05%
# Train Loss: 1.7734, Train Acc: 38.70%
# Validation Loss: 1.8168, Validation Acc: 37.05%
#
# Epoch 67/100 - Training
# [========================================] 625/625 | Loss: 1.778 | Accuracy: 38.17%
# Epoch 67/100 - Evaluation
# [========================================] 157/157 | Loss: 1.811 | Accuracy: 37.40%
# Train Loss: 1.7777, Train Acc: 38.17%
# Validation Loss: 1.8110, Validation Acc: 37.40%
#
# Epoch 68/100 - Training
# [========================================] 625/625 | Loss: 1.773 | Accuracy: 38.49%
# Epoch 68/100 - Evaluation
# [========================================] 157/157 | Loss: 1.824 | Accuracy: 36.32%
# Train Loss: 1.7734, Train Acc: 38.49%
# Validation Loss: 1.8236, Validation Acc: 36.32%
#
# Epoch 69/100 - Training
# [========================================] 625/625 | Loss: 1.775 | Accuracy: 38.26%
# Epoch 69/100 - Evaluation
# [========================================] 157/157 | Loss: 1.820 | Accuracy: 36.61%
# Train Loss: 1.7745, Train Acc: 38.26%
# Validation Loss: 1.8199, Validation Acc: 36.61%
#
# Epoch 70/100 - Training
# [========================================] 625/625 | Loss: 1.771 | Accuracy: 38.57%
# Epoch 70/100 - Evaluation
# [========================================] 157/157 | Loss: 1.816 | Accuracy: 36.90%
# Train Loss: 1.7714, Train Acc: 38.57%
# Validation Loss: 1.8164, Validation Acc: 36.90%
#
# Epoch 71/100 - Training
# [========================================] 625/625 | Loss: 1.773 | Accuracy: 38.45%
# Epoch 71/100 - Evaluation
# [========================================] 157/157 | Loss: 1.825 | Accuracy: 36.69%
# Train Loss: 1.7726, Train Acc: 38.45%
# Validation Loss: 1.8252, Validation Acc: 36.69%
#
# Epoch 72/100 - Training
# [========================================] 625/625 | Loss: 1.773 | Accuracy: 38.60%
# Epoch 72/100 - Evaluation
# [========================================] 157/157 | Loss: 1.822 | Accuracy: 36.83%
# Train Loss: 1.7733, Train Acc: 38.60%
# Validation Loss: 1.8223, Validation Acc: 36.83%
#
# Epoch 73/100 - Training
# [========================================] 625/625 | Loss: 1.769 | Accuracy: 38.60%
# Epoch 73/100 - Evaluation
# [========================================] 157/157 | Loss: 1.822 | Accuracy: 37.17%
# Train Loss: 1.7691, Train Acc: 38.60%
# Validation Loss: 1.8220, Validation Acc: 37.17%
#
# Epoch 74/100 - Training
# [========================================] 625/625 | Loss: 1.771 | Accuracy: 38.54%
# Epoch 74/100 - Evaluation
# [========================================] 157/157 | Loss: 1.821 | Accuracy: 37.07%
# Train Loss: 1.7708, Train Acc: 38.54%
# Validation Loss: 1.8207, Validation Acc: 37.07%
#
# Epoch 75/100 - Training
# [========================================] 625/625 | Loss: 1.770 | Accuracy: 38.64%
# Epoch 75/100 - Evaluation
# [========================================] 157/157 | Loss: 1.809 | Accuracy: 37.46%
# Train Loss: 1.7703, Train Acc: 38.64%
# Validation Loss: 1.8087, Validation Acc: 37.46%
#
# Epoch 76/100 - Training
# [========================================] 625/625 | Loss: 1.773 | Accuracy: 38.52%
# Epoch 76/100 - Evaluation
# [========================================] 157/157 | Loss: 1.813 | Accuracy: 36.57%
# Train Loss: 1.7728, Train Acc: 38.52%
# Validation Loss: 1.8127, Validation Acc: 36.57%
#
# Epoch 77/100 - Training
# [========================================] 625/625 | Loss: 1.770 | Accuracy: 38.76%
# Epoch 77/100 - Evaluation
# [========================================] 157/157 | Loss: 1.814 | Accuracy: 36.91%
# Train Loss: 1.7702, Train Acc: 38.76%
# Validation Loss: 1.8136, Validation Acc: 36.91%
#
# Epoch 78/100 - Training
# [========================================] 625/625 | Loss: 1.771 | Accuracy: 38.54%
# Epoch 78/100 - Evaluation
# [========================================] 157/157 | Loss: 1.820 | Accuracy: 36.91%
# Train Loss: 1.7712, Train Acc: 38.54%
# Validation Loss: 1.8195, Validation Acc: 36.91%
#
# Epoch 79/100 - Training
# [========================================] 625/625 | Loss: 1.770 | Accuracy: 38.38%
# Epoch 79/100 - Evaluation
# [========================================] 157/157 | Loss: 1.819 | Accuracy: 36.84%
# Train Loss: 1.7699, Train Acc: 38.38%
# Validation Loss: 1.8192, Validation Acc: 36.84%
#
# Epoch 80/100 - Training
# [========================================] 625/625 | Loss: 1.774 | Accuracy: 38.45%
# Epoch 80/100 - Evaluation
# [========================================] 157/157 | Loss: 1.814 | Accuracy: 36.77%Early stopping at epoch 80 with best validation loss: 1.8074
#
# Training complete in 146m 9s.

# %%
plot_result(result_kan)

# %%
kan_results = evaluate_test_set(
    model=shallow_kan,
    testloader=testloader,
    criterion=criterion,
    model_path="model_20250504_093126_59.pt",
    device=device,
    input_dim=input_dim
)
# Out:
# Test Loss: 1.7896, Test Accuracy: 37.85%

# %%
# Confusion matrix
cm = confusion_matrix(kan_results[2], kan_results[3])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=full_dataset.classes)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - Test Set")
plt.show()
