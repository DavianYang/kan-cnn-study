# %% [markdown]
# <a href="https://colab.research.google.com/github/DavianYang/kan-cnn-study/blob/main/shallow_mlp_kan_cifar10_with_aug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
from torchvision.transforms import v2
import torchvision.models as models
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import DataLoader

import math
import matplotlib.pyplot as plt
import time
import wandb

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# https://github.com/Blealtan/efficient-kan/tree/master/src/efficient_kan

import torch
import torch.nn.functional as F
import math


class KANLinear(torch.nn.Module):
    def __init__(
        self,
        in_features,
        out_features,
        grid_size=5,
        spline_order=3,
        scale_noise=0.1,
        scale_base=1.0,
        scale_spline=1.0,
        enable_standalone_scale_spline=True,
        base_activation=torch.nn.SiLU,
        grid_eps=0.02,
        grid_range=[-1, 1],
    ):
        super(KANLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.grid_size = grid_size
        self.spline_order = spline_order

        h = (grid_range[1] - grid_range[0]) / grid_size
        grid = (
            (
                torch.arange(-spline_order, grid_size + spline_order + 1) * h
                + grid_range[0]
            )
            .expand(in_features, -1)
            .contiguous()
        )
        self.register_buffer("grid", grid)

        self.base_weight = torch.nn.Parameter(torch.Tensor(out_features, in_features))
        self.spline_weight = torch.nn.Parameter(
            torch.Tensor(out_features, in_features, grid_size + spline_order)
        )
        if enable_standalone_scale_spline:
            self.spline_scaler = torch.nn.Parameter(
                torch.Tensor(out_features, in_features)
            )

        self.scale_noise = scale_noise
        self.scale_base = scale_base
        self.scale_spline = scale_spline
        self.enable_standalone_scale_spline = enable_standalone_scale_spline
        self.base_activation = base_activation()
        self.grid_eps = grid_eps

        self.reset_parameters()

    def reset_parameters(self):
        torch.nn.init.kaiming_uniform_(self.base_weight, a=math.sqrt(5) * self.scale_base)
        with torch.no_grad():
            noise = (
                (
                    torch.rand(self.grid_size + 1, self.in_features, self.out_features)
                    - 1 / 2
                )
                * self.scale_noise
                / self.grid_size
            )
            self.spline_weight.data.copy_(
                (self.scale_spline if not self.enable_standalone_scale_spline else 1.0)
                * self.curve2coeff(
                    self.grid.T[self.spline_order : -self.spline_order],
                    noise,
                )
            )
            if self.enable_standalone_scale_spline:
                # torch.nn.init.constant_(self.spline_scaler, self.scale_spline)
                torch.nn.init.kaiming_uniform_(self.spline_scaler, a=math.sqrt(5) * self.scale_spline)

    def b_splines(self, x: torch.Tensor):
        """
        Compute the B-spline bases for the given input tensor.

        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, in_features).

        Returns:
            torch.Tensor: B-spline bases tensor of shape (batch_size, in_features, grid_size + spline_order).
        """
        assert x.dim() == 2 and x.size(1) == self.in_features

        grid: torch.Tensor = (
            self.grid
        )  # (in_features, grid_size + 2 * spline_order + 1)
        x = x.unsqueeze(-1)
        bases = ((x >= grid[:, :-1]) & (x < grid[:, 1:])).to(x.dtype)
        for k in range(1, self.spline_order + 1):
            bases = (
                (x - grid[:, : -(k + 1)])
                / (grid[:, k:-1] - grid[:, : -(k + 1)])
                * bases[:, :, :-1]
            ) + (
                (grid[:, k + 1 :] - x)
                / (grid[:, k + 1 :] - grid[:, 1:(-k)])
                * bases[:, :, 1:]
            )

        assert bases.size() == (
            x.size(0),
            self.in_features,
            self.grid_size + self.spline_order,
        )
        return bases.contiguous()

    def curve2coeff(self, x: torch.Tensor, y: torch.Tensor):
        """
        Compute the coefficients of the curve that interpolates the given points.

        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, in_features).
            y (torch.Tensor): Output tensor of shape (batch_size, in_features, out_features).

        Returns:
            torch.Tensor: Coefficients tensor of shape (out_features, in_features, grid_size + spline_order).
        """
        assert x.dim() == 2 and x.size(1) == self.in_features
        assert y.size() == (x.size(0), self.in_features, self.out_features)

        A = self.b_splines(x).transpose(
            0, 1
        )  # (in_features, batch_size, grid_size + spline_order)
        B = y.transpose(0, 1)  # (in_features, batch_size, out_features)
        solution = torch.linalg.lstsq(
            A, B
        ).solution  # (in_features, grid_size + spline_order, out_features)
        result = solution.permute(
            2, 0, 1
        )  # (out_features, in_features, grid_size + spline_order)

        assert result.size() == (
            self.out_features,
            self.in_features,
            self.grid_size + self.spline_order,
        )
        return result.contiguous()

    @property
    def scaled_spline_weight(self):
        return self.spline_weight * (
            self.spline_scaler.unsqueeze(-1)
            if self.enable_standalone_scale_spline
            else 1.0
        )

    def forward(self, x: torch.Tensor):
        assert x.size(-1) == self.in_features
        original_shape = x.shape
        x = x.reshape(-1, self.in_features)

        base_output = F.linear(self.base_activation(x), self.base_weight)
        spline_output = F.linear(
            self.b_splines(x).view(x.size(0), -1),
            self.scaled_spline_weight.view(self.out_features, -1),
        )
        output = base_output + spline_output

        output = output.reshape(*original_shape[:-1], self.out_features)
        return output

    @torch.no_grad()
    def update_grid(self, x: torch.Tensor, margin=0.01):
        assert x.dim() == 2 and x.size(1) == self.in_features
        batch = x.size(0)

        splines = self.b_splines(x)  # (batch, in, coeff)
        splines = splines.permute(1, 0, 2)  # (in, batch, coeff)
        orig_coeff = self.scaled_spline_weight  # (out, in, coeff)
        orig_coeff = orig_coeff.permute(1, 2, 0)  # (in, coeff, out)
        unreduced_spline_output = torch.bmm(splines, orig_coeff)  # (in, batch, out)
        unreduced_spline_output = unreduced_spline_output.permute(
            1, 0, 2
        )  # (batch, in, out)

        # sort each channel individually to collect data distribution
        x_sorted = torch.sort(x, dim=0)[0]
        grid_adaptive = x_sorted[
            torch.linspace(
                0, batch - 1, self.grid_size + 1, dtype=torch.int64, device=x.device
            )
        ]

        uniform_step = (x_sorted[-1] - x_sorted[0] + 2 * margin) / self.grid_size
        grid_uniform = (
            torch.arange(
                self.grid_size + 1, dtype=torch.float32, device=x.device
            ).unsqueeze(1)
            * uniform_step
            + x_sorted[0]
            - margin
        )

        grid = self.grid_eps * grid_uniform + (1 - self.grid_eps) * grid_adaptive
        grid = torch.concatenate(
            [
                grid[:1]
                - uniform_step
                * torch.arange(self.spline_order, 0, -1, device=x.device).unsqueeze(1),
                grid,
                grid[-1:]
                + uniform_step
                * torch.arange(1, self.spline_order + 1, device=x.device).unsqueeze(1),
            ],
            dim=0,
        )

        self.grid.copy_(grid.T)
        self.spline_weight.data.copy_(self.curve2coeff(x, unreduced_spline_output))

    def regularization_loss(self, regularize_activation=1.0, regularize_entropy=1.0):
        """
        Compute the regularization loss.

        This is a dumb simulation of the original L1 regularization as stated in the
        paper, since the original one requires computing absolutes and entropy from the
        expanded (batch, in_features, out_features) intermediate tensor, which is hidden
        behind the F.linear function if we want an memory efficient implementation.

        The L1 regularization is now computed as mean absolute value of the spline
        weights. The authors implementation also includes this term in addition to the
        sample-based regularization.
        """
        l1_fake = self.spline_weight.abs().mean(-1)
        regularization_loss_activation = l1_fake.sum()
        p = l1_fake / regularization_loss_activation
        regularization_loss_entropy = -torch.sum(p * p.log())
        return (
            regularize_activation * regularization_loss_activation
            + regularize_entropy * regularization_loss_entropy
        )


class KAN(torch.nn.Module):
    def __init__(
        self,
        layers_hidden,
        grid_size=5,
        spline_order=3,
        scale_noise=0.1,
        scale_base=1.0,
        scale_spline=1.0,
        base_activation=torch.nn.SiLU,
        grid_eps=0.02,
        grid_range=[-1, 1],
    ):
        super(KAN, self).__init__()
        self.grid_size = grid_size
        self.spline_order = spline_order

        self.layers = torch.nn.ModuleList()
        for in_features, out_features in zip(layers_hidden, layers_hidden[1:]):
            self.layers.append(
                KANLinear(
                    in_features,
                    out_features,
                    grid_size=grid_size,
                    spline_order=spline_order,
                    scale_noise=scale_noise,
                    scale_base=scale_base,
                    scale_spline=scale_spline,
                    base_activation=base_activation,
                    grid_eps=grid_eps,
                    grid_range=grid_range,
                )
            )

    def forward(self, x: torch.Tensor, update_grid=False):
        for layer in self.layers:
            if update_grid:
                layer.update_grid(x)
            x = layer(x)
        return x

    def regularization_loss(self, regularize_activation=1.0, regularize_entropy=1.0):
        return sum(
            layer.regularization_loss(regularize_activation, regularize_entropy)
            for layer in self.layers
        )

# %%
# Define color codes for terminal
class Colors:
    RESET = '\033[0m'
    GREEN = '\033[92m'
    RED = '\033[91m'
    YELLOW = '\033[93m'
    CYAN = '\033[96m'

def display_progress_bar(batch_idx, num_batches, loss, accuracy):
    """
    Function to display a colored progress bar.
    Args:
        batch_idx: Current batch index
        num_batches: Total number of batches
        loss: Current loss value
        accuracy: Current accuracy value
    """
    progress = (batch_idx + 1) / num_batches
    bar_length = 40  # Length of the progress bar (number of '==' chars)
    filled_length = int(bar_length * progress)
    bar = f"{Colors.GREEN}{'=' * filled_length}{Colors.RED}{'-' * (bar_length - filled_length)}{Colors.RESET}"

    print(f'\r[{bar}] {batch_idx + 1}/{num_batches} | {Colors.YELLOW}Loss:{Colors.RESET} {loss:.3f} | {Colors.YELLOW}Accuracy:{Colors.RESET} {accuracy:.2f}%', end='', flush=True)

# %%
import matplotlib.pyplot as plt

def plot_result(history, title="Training Progress"):
    epochs = range(1, len(history['train_loss']) + 1)

    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['train_loss'], label='Train', color='tomato')
    plt.plot(epochs, history['val_loss'], label='Validation', color='steelblue')
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(frameon=False)
    plt.grid(True, linestyle="--", alpha=0.3)

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['train_acc'], label='Train', color='mediumseagreen')
    plt.plot(epochs, history['val_acc'], label='Validation', color='black')
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(frameon=False)
    plt.grid(True, linestyle="--", alpha=0.3)

    plt.suptitle(title, fontsize=14)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %%
def train_model(model, trainloader, valloader, device,
                             optimizer, criterion, epochs=10, input_dim=None,
                             use_wandb=False, project_name=None, show_progress=True):
    model.to(device)
    start_time = time.time()

    train_loss_values, train_acc_values = [], []
    val_loss_values, val_acc_values = [], []

    if use_wandb:
        wandb.init(project=project_name)
        wandb.watch(model, log="all")

    for epoch in range(epochs):
        # ---------- Training ----------
        model.train()
        train_loss, correct, total = 0.0, 0, 0
        num_train_batches = len(trainloader)

        print(f"\nEpoch {epoch + 1}/{epochs} - Training")

        for batch_idx, (inputs, targets) in enumerate(trainloader):
            if input_dim is not None:
                inputs = inputs.view(-1, input_dim * input_dim * 3).to(device)
            else:
                inputs = inputs.to(device)
            targets = targets.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

            if show_progress:
                acc = 100. * correct / total
                avg_loss = train_loss / (batch_idx + 1)
                display_progress_bar(batch_idx, num_train_batches, avg_loss, acc)

        train_epoch_loss = train_loss / num_train_batches
        train_epoch_acc = 100. * correct / total
        train_loss_values.append(train_epoch_loss)
        train_acc_values.append(train_epoch_acc)

        # ---------- Evaluation ----------
        model.eval()
        val_loss, correct, total = 0.0, 0, 0
        all_preds, all_targets = [], []
        num_val_batches = len(valloader)

        print(f"\nEpoch {epoch + 1}/{epochs} - Evaluation")

        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(valloader):
                if input_dim is not None:
                    inputs = inputs.view(-1, input_dim * input_dim * 3).to(device)
                else:
                    inputs = inputs.to(device)
                targets = targets.to(device)

                outputs = model(inputs)
                loss = criterion(outputs, targets)

                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += targets.size(0)
                correct += predicted.eq(targets).sum().item()

                all_preds.extend(predicted.cpu().numpy())
                all_targets.extend(targets.cpu().numpy())

                if show_progress:
                    acc = 100. * correct / total
                    avg_loss = val_loss / (batch_idx + 1)
                    display_progress_bar(batch_idx, num_val_batches, avg_loss, acc)

        val_epoch_loss = val_loss / num_val_batches
        val_epoch_acc = 100. * correct / total
        val_loss_values.append(val_epoch_loss)
        val_acc_values.append(val_epoch_acc)

        print(f"\nTrain Loss: {train_epoch_loss:.4f}, Train Acc: {train_epoch_acc:.2f}%")
        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Acc: {val_epoch_acc:.2f}%")

        if use_wandb:
            wandb.log({
                "Train Loss": train_epoch_loss,
                "Train Accuracy": train_epoch_acc,
                "Validation Loss": val_epoch_loss,
                "Validation Accuracy": val_epoch_acc,
                "Epoch": epoch + 1
            })

    elapsed = time.time() - start_time
    print(f"\nTraining complete in {elapsed // 60:.0f}m {elapsed % 60:.0f}s.")

    if use_wandb:
        wandb.finish()

    return {
        "model": model,
        "train_loss": train_loss_values,
        "train_acc": train_acc_values,
        "val_loss": val_loss_values,
        "val_acc": val_acc_values,
        "predictions": all_preds,
        "targets": all_targets
    }

# %%
def count_parameters(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total_params, trainable_params

# %%
class ShallowNet(nn.Module):
  def __init__(self, height, width, depth, classes):
    super(ShallowNet, self).__init__()

    self.conv1 = nn.Conv2d(in_channels=depth, out_channels=32, kernel_size=3, padding='same')
    self.fc1 = nn.Linear(32 * height * width, classes)

  def forward(self, x):
    x = self.conv1(x)
    x = F.relu(x)
    x = torch.flatten(x, 1)
    x = self.fc1(x)

    return x

# %%
classes = 10
input_dim = 32
lr = 0.001
epochs = 30
batch_size = 64

transform = v2.Compose([
    v2.RandomCrop(32, padding=4),
    v2.RandomHorizontalFlip(),
    v2.ToTensor(),
    v2.Normalize(mean=[0.4914, 0.4822, 0.4465],
                         std=[0.2023, 0.1994, 0.2010]),
])

# Load CIFAR-10 dataset
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
valset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

trainloader = DataLoader(trainset, batch_size, shuffle=True)
valloader = DataLoader(valset, batch_size, shuffle=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
# 100%|██████████| 170M/170M [00:03<00:00, 48.4MB/s]

# %%
shallow_mlp = ShallowNet(height=32, width=32, depth=3, classes=10)

total_params_mlp, trainable_params_mlp = count_parameters(shallow_mlp)
print(f"Total parameters: {total_params_mlp}")
print(f"Trainable parameters: {trainable_params_mlp}")

optimizer = optim.AdamW(shallow_mlp.parameters(), lr=lr,weight_decay=0.01)
criterion = nn.CrossEntropyLoss()
# Out:
# Total parameters: 328586
# Trainable parameters: 328586

# %%
result = train_model(shallow_mlp, trainloader, valloader, device, optimizer, criterion, epochs)
# Out:
# Epoch 1/30 - Training
# [========================================] 782/782 | Loss: 1.723 | Accuracy: 41.02%
# Epoch 1/30 - Evaluation
# [========================================] 157/157 | Loss: 1.511 | Accuracy: 45.74%
# Train Loss: 1.7226, Train Acc: 41.02%
# Validation Loss: 1.5107, Validation Acc: 45.74%
#
# Epoch 2/30 - Training
# [========================================] 782/782 | Loss: 1.434 | Accuracy: 49.66%
# Epoch 2/30 - Evaluation
# [========================================] 157/157 | Loss: 1.415 | Accuracy: 49.03%
# Train Loss: 1.4342, Train Acc: 49.66%
# Validation Loss: 1.4153, Validation Acc: 49.03%
#
# Epoch 3/30 - Training
# [========================================] 782/782 | Loss: 1.363 | Accuracy: 52.19%
# Epoch 3/30 - Evaluation
# [========================================] 157/157 | Loss: 1.340 | Accuracy: 53.17%
# Train Loss: 1.3631, Train Acc: 52.19%
# Validation Loss: 1.3395, Validation Acc: 53.17%
#
# Epoch 4/30 - Training
# [========================================] 782/782 | Loss: 1.323 | Accuracy: 53.75%
# Epoch 4/30 - Evaluation
# [========================================] 157/157 | Loss: 1.287 | Accuracy: 56.21%
# Train Loss: 1.3235, Train Acc: 53.75%
# Validation Loss: 1.2874, Validation Acc: 56.21%
#
# Epoch 5/30 - Training
# [========================================] 782/782 | Loss: 1.299 | Accuracy: 55.10%
# Epoch 5/30 - Evaluation
# [========================================] 157/157 | Loss: 1.307 | Accuracy: 55.00%
# Train Loss: 1.2991, Train Acc: 55.10%
# Validation Loss: 1.3065, Validation Acc: 55.00%
#
# Epoch 6/30 - Training
# [========================================] 782/782 | Loss: 1.277 | Accuracy: 56.18%
# Epoch 6/30 - Evaluation
# [========================================] 157/157 | Loss: 1.260 | Accuracy: 56.55%
# Train Loss: 1.2774, Train Acc: 56.18%
# Validation Loss: 1.2604, Validation Acc: 56.55%
#
# Epoch 7/30 - Training
# [========================================] 782/782 | Loss: 1.266 | Accuracy: 56.33%
# Epoch 7/30 - Evaluation
# [========================================] 157/157 | Loss: 1.256 | Accuracy: 56.59%
# Train Loss: 1.2665, Train Acc: 56.33%
# Validation Loss: 1.2563, Validation Acc: 56.59%
#
# Epoch 8/30 - Training
# [========================================] 782/782 | Loss: 1.259 | Accuracy: 56.58%
# Epoch 8/30 - Evaluation
# [========================================] 157/157 | Loss: 1.315 | Accuracy: 54.89%
# Train Loss: 1.2590, Train Acc: 56.58%
# Validation Loss: 1.3146, Validation Acc: 54.89%
#
# Epoch 9/30 - Training
# [========================================] 782/782 | Loss: 1.250 | Accuracy: 57.00%
# Epoch 9/30 - Evaluation
# [========================================] 157/157 | Loss: 1.280 | Accuracy: 55.87%
# Train Loss: 1.2496, Train Acc: 57.00%
# Validation Loss: 1.2803, Validation Acc: 55.87%
#
# Epoch 10/30 - Training
# [========================================] 782/782 | Loss: 1.242 | Accuracy: 57.44%
# Epoch 10/30 - Evaluation
# [========================================] 157/157 | Loss: 1.256 | Accuracy: 57.01%
# Train Loss: 1.2419, Train Acc: 57.44%
# Validation Loss: 1.2558, Validation Acc: 57.01%
#
# Epoch 11/30 - Training
# [========================================] 782/782 | Loss: 1.236 | Accuracy: 57.73%
# Epoch 11/30 - Evaluation
# [========================================] 157/157 | Loss: 1.233 | Accuracy: 57.25%
# Train Loss: 1.2361, Train Acc: 57.73%
# Validation Loss: 1.2326, Validation Acc: 57.25%
#
# Epoch 12/30 - Training
# [========================================] 782/782 | Loss: 1.231 | Accuracy: 57.58%
# Epoch 12/30 - Evaluation
# [========================================] 157/157 | Loss: 1.238 | Accuracy: 57.85%
# Train Loss: 1.2307, Train Acc: 57.58%
# Validation Loss: 1.2380, Validation Acc: 57.85%
#
# Epoch 13/30 - Training
# [========================================] 782/782 | Loss: 1.226 | Accuracy: 58.15%
# Epoch 13/30 - Evaluation
# [========================================] 157/157 | Loss: 1.248 | Accuracy: 57.34%
# Train Loss: 1.2257, Train Acc: 58.15%
# Validation Loss: 1.2480, Validation Acc: 57.34%
#
# Epoch 14/30 - Training
# [========================================] 782/782 | Loss: 1.226 | Accuracy: 57.94%
# Epoch 14/30 - Evaluation
# [========================================] 157/157 | Loss: 1.270 | Accuracy: 56.71%
# Train Loss: 1.2255, Train Acc: 57.94%
# Validation Loss: 1.2697, Validation Acc: 56.71%
#
# Epoch 15/30 - Training
# [========================================] 782/782 | Loss: 1.222 | Accuracy: 57.97%
# Epoch 15/30 - Evaluation
# [========================================] 157/157 | Loss: 1.235 | Accuracy: 57.85%
# Train Loss: 1.2218, Train Acc: 57.97%
# Validation Loss: 1.2353, Validation Acc: 57.85%
#
# Epoch 16/30 - Training
# [========================================] 782/782 | Loss: 1.213 | Accuracy: 58.39%
# Epoch 16/30 - Evaluation
# [========================================] 157/157 | Loss: 1.196 | Accuracy: 58.81%
# Train Loss: 1.2129, Train Acc: 58.39%
# Validation Loss: 1.1962, Validation Acc: 58.81%
#
# Epoch 17/30 - Training
# [========================================] 782/782 | Loss: 1.212 | Accuracy: 58.41%
# Epoch 17/30 - Evaluation
# [========================================] 157/157 | Loss: 1.211 | Accuracy: 58.72%
# Train Loss: 1.2118, Train Acc: 58.41%
# Validation Loss: 1.2109, Validation Acc: 58.72%
#
# Epoch 18/30 - Training
# [========================================] 782/782 | Loss: 1.205 | Accuracy: 58.69%
# Epoch 18/30 - Evaluation
# [========================================] 157/157 | Loss: 1.264 | Accuracy: 58.23%
# Train Loss: 1.2051, Train Acc: 58.69%
# Validation Loss: 1.2641, Validation Acc: 58.23%
#
# Epoch 19/30 - Training
# [========================================] 782/782 | Loss: 1.201 | Accuracy: 58.83%
# Epoch 19/30 - Evaluation
# [========================================] 157/157 | Loss: 1.205 | Accuracy: 58.04%
# Train Loss: 1.2007, Train Acc: 58.83%
# Validation Loss: 1.2047, Validation Acc: 58.04%
#
# Epoch 20/30 - Training
# [========================================] 782/782 | Loss: 1.200 | Accuracy: 58.87%
# Epoch 20/30 - Evaluation
# [========================================] 157/157 | Loss: 1.197 | Accuracy: 59.67%
# Train Loss: 1.1997, Train Acc: 58.87%
# Validation Loss: 1.1974, Validation Acc: 59.67%
#
# Epoch 21/30 - Training
# [========================================] 782/782 | Loss: 1.193 | Accuracy: 59.09%
# Epoch 21/30 - Evaluation
# [========================================] 157/157 | Loss: 1.196 | Accuracy: 58.36%
# Train Loss: 1.1934, Train Acc: 59.09%
# Validation Loss: 1.1960, Validation Acc: 58.36%
#
# Epoch 22/30 - Training
# [========================================] 782/782 | Loss: 1.193 | Accuracy: 58.90%
# Epoch 22/30 - Evaluation
# [========================================] 157/157 | Loss: 1.249 | Accuracy: 57.65%
# Train Loss: 1.1933, Train Acc: 58.90%
# Validation Loss: 1.2493, Validation Acc: 57.65%
#
# Epoch 23/30 - Training
# [========================================] 782/782 | Loss: 1.191 | Accuracy: 59.33%
# Epoch 23/30 - Evaluation
# [========================================] 157/157 | Loss: 1.199 | Accuracy: 59.09%
# Train Loss: 1.1911, Train Acc: 59.33%
# Validation Loss: 1.1992, Validation Acc: 59.09%
#
# Epoch 24/30 - Training
# [========================================] 782/782 | Loss: 1.191 | Accuracy: 59.21%
# Epoch 24/30 - Evaluation
# [========================================] 157/157 | Loss: 1.223 | Accuracy: 58.43%
# Train Loss: 1.1907, Train Acc: 59.21%
# Validation Loss: 1.2227, Validation Acc: 58.43%
#
# Epoch 25/30 - Training
# [========================================] 782/782 | Loss: 1.180 | Accuracy: 59.40%
# Epoch 25/30 - Evaluation
# [========================================] 157/157 | Loss: 1.203 | Accuracy: 58.87%
# Train Loss: 1.1802, Train Acc: 59.40%
# Validation Loss: 1.2033, Validation Acc: 58.87%
#
# Epoch 26/30 - Training
# [========================================] 782/782 | Loss: 1.175 | Accuracy: 59.65%
# Epoch 26/30 - Evaluation
# [========================================] 157/157 | Loss: 1.208 | Accuracy: 58.47%
# Train Loss: 1.1747, Train Acc: 59.65%
# Validation Loss: 1.2077, Validation Acc: 58.47%
#
# Epoch 27/30 - Training
# [========================================] 782/782 | Loss: 1.183 | Accuracy: 59.55%
# Epoch 27/30 - Evaluation
# [========================================] 157/157 | Loss: 1.188 | Accuracy: 58.92%
# Train Loss: 1.1830, Train Acc: 59.55%
# Validation Loss: 1.1880, Validation Acc: 58.92%
#
# Epoch 28/30 - Training
# [========================================] 782/782 | Loss: 1.178 | Accuracy: 59.69%
# Epoch 28/30 - Evaluation
# [========================================] 157/157 | Loss: 1.191 | Accuracy: 58.87%
# Train Loss: 1.1781, Train Acc: 59.69%
# Validation Loss: 1.1905, Validation Acc: 58.87%
#
# Epoch 29/30 - Training
# [========================================] 782/782 | Loss: 1.182 | Accuracy: 59.56%
# Epoch 29/30 - Evaluation
# [========================================] 157/157 | Loss: 1.181 | Accuracy: 59.81%
# Train Loss: 1.1816, Train Acc: 59.56%
# Validation Loss: 1.1811, Validation Acc: 59.81%
#
# Epoch 30/30 - Training
# [========================================] 782/782 | Loss: 1.177 | Accuracy: 59.76%
# Epoch 30/30 - Evaluation
# [========================================] 157/157 | Loss: 1.181 | Accuracy: 59.27%
# Train Loss: 1.1773, Train Acc: 59.76%
# Validation Loss: 1.1811, Validation Acc: 59.27%
#
# Training complete in 13m 38s.

# %%
plot_result(result)

# %%
shallow_kan = KAN([input_dim * input_dim * 3, classes], grid_size=5, spline_order=3)

total_params_kan, trainable_params_kan = count_parameters(shallow_kan)
print(f"Total parameters: {total_params_kan}")
print(f"Trainable parameters: {trainable_params_kan}")

optimizer = optim.AdamW(shallow_kan.parameters(), lr=lr, weight_decay=0.01)
criterion = nn.CrossEntropyLoss()
# Out:
# Total parameters: 307200
# Trainable parameters: 307200

# %%
result_kan = train_model(shallow_kan, trainloader, valloader, device,
                                  optimizer, criterion,
                                  epochs, input_dim)
# Out:
# Epoch 1/30 - Training
# [========================================] 782/782 | Loss: 2.047 | Accuracy: 29.67%
# Epoch 1/30 - Evaluation
# [========================================] 157/157 | Loss: 1.981 | Accuracy: 32.47%
# Train Loss: 2.0467, Train Acc: 29.67%
# Validation Loss: 1.9811, Validation Acc: 32.47%
#
# Epoch 2/30 - Training
# [========================================] 782/782 | Loss: 1.999 | Accuracy: 32.06%
# Epoch 2/30 - Evaluation
# [========================================] 157/157 | Loss: 2.125 | Accuracy: 30.45%
# Train Loss: 1.9987, Train Acc: 32.06%
# Validation Loss: 2.1255, Validation Acc: 30.45%
#
# Epoch 3/30 - Training
# [========================================] 782/782 | Loss: 1.991 | Accuracy: 32.47%
# Epoch 3/30 - Evaluation
# [========================================] 157/157 | Loss: 2.108 | Accuracy: 30.11%
# Train Loss: 1.9910, Train Acc: 32.47%
# Validation Loss: 2.1084, Validation Acc: 30.11%
#
# Epoch 4/30 - Training
# [========================================] 782/782 | Loss: 1.987 | Accuracy: 32.53%
# Epoch 4/30 - Evaluation
# [========================================] 157/157 | Loss: 2.038 | Accuracy: 29.91%
# Train Loss: 1.9874, Train Acc: 32.53%
# Validation Loss: 2.0383, Validation Acc: 29.91%
#
# Epoch 5/30 - Training
# [========================================] 782/782 | Loss: 1.975 | Accuracy: 32.96%
# Epoch 5/30 - Evaluation
# [========================================] 157/157 | Loss: 1.952 | Accuracy: 32.71%
# Train Loss: 1.9751, Train Acc: 32.96%
# Validation Loss: 1.9515, Validation Acc: 32.71%
#
# Epoch 6/30 - Training
# [========================================] 782/782 | Loss: 1.972 | Accuracy: 33.39%
# Epoch 6/30 - Evaluation
# [========================================] 157/157 | Loss: 1.946 | Accuracy: 33.44%
# Train Loss: 1.9722, Train Acc: 33.39%
# Validation Loss: 1.9462, Validation Acc: 33.44%
#
# Epoch 7/30 - Training
# [========================================] 782/782 | Loss: 1.969 | Accuracy: 33.24%
# Epoch 7/30 - Evaluation
# [========================================] 157/157 | Loss: 1.941 | Accuracy: 33.98%
# Train Loss: 1.9689, Train Acc: 33.24%
# Validation Loss: 1.9409, Validation Acc: 33.98%
#
# Epoch 8/30 - Training
# [========================================] 782/782 | Loss: 1.969 | Accuracy: 33.19%
# Epoch 8/30 - Evaluation
# [========================================] 157/157 | Loss: 2.093 | Accuracy: 31.84%
# Train Loss: 1.9695, Train Acc: 33.19%
# Validation Loss: 2.0927, Validation Acc: 31.84%
#
# Epoch 9/30 - Training
# [========================================] 782/782 | Loss: 1.970 | Accuracy: 33.37%
# Epoch 9/30 - Evaluation
# [========================================] 157/157 | Loss: 1.963 | Accuracy: 33.90%
# Train Loss: 1.9702, Train Acc: 33.37%
# Validation Loss: 1.9634, Validation Acc: 33.90%
#
# Epoch 10/30 - Training
# [========================================] 782/782 | Loss: 1.974 | Accuracy: 33.35%
# Epoch 10/30 - Evaluation
# [========================================] 157/157 | Loss: 1.934 | Accuracy: 33.52%
# Train Loss: 1.9744, Train Acc: 33.35%
# Validation Loss: 1.9338, Validation Acc: 33.52%
#
# Epoch 11/30 - Training
# [========================================] 782/782 | Loss: 1.969 | Accuracy: 33.28%
# Epoch 11/30 - Evaluation
# [========================================] 157/157 | Loss: 1.998 | Accuracy: 31.95%
# Train Loss: 1.9691, Train Acc: 33.28%
# Validation Loss: 1.9980, Validation Acc: 31.95%
#
# Epoch 12/30 - Training
# [========================================] 782/782 | Loss: 1.967 | Accuracy: 33.48%
# Epoch 12/30 - Evaluation
# [========================================] 157/157 | Loss: 1.951 | Accuracy: 33.86%
# Train Loss: 1.9669, Train Acc: 33.48%
# Validation Loss: 1.9506, Validation Acc: 33.86%
#
# Epoch 13/30 - Training
# [========================================] 782/782 | Loss: 1.965 | Accuracy: 33.71%
# Epoch 13/30 - Evaluation
# [========================================] 157/157 | Loss: 1.989 | Accuracy: 33.73%
# Train Loss: 1.9650, Train Acc: 33.71%
# Validation Loss: 1.9886, Validation Acc: 33.73%
#
# Epoch 14/30 - Training
# [========================================] 782/782 | Loss: 1.980 | Accuracy: 33.07%
# Epoch 14/30 - Evaluation
# [========================================] 157/157 | Loss: 1.979 | Accuracy: 33.35%
# Train Loss: 1.9798, Train Acc: 33.07%
# Validation Loss: 1.9793, Validation Acc: 33.35%
#
# Epoch 15/30 - Training
# [========================================] 782/782 | Loss: 1.967 | Accuracy: 33.67%
# Epoch 15/30 - Evaluation
# [========================================] 157/157 | Loss: 1.996 | Accuracy: 33.81%
# Train Loss: 1.9674, Train Acc: 33.67%
# Validation Loss: 1.9959, Validation Acc: 33.81%
#
# Epoch 16/30 - Training
# [========================================] 782/782 | Loss: 1.958 | Accuracy: 33.97%
# Epoch 16/30 - Evaluation
# [========================================] 157/157 | Loss: 1.980 | Accuracy: 31.56%
# Train Loss: 1.9575, Train Acc: 33.97%
# Validation Loss: 1.9802, Validation Acc: 31.56%
#
# Epoch 17/30 - Training
# [========================================] 782/782 | Loss: 1.963 | Accuracy: 33.95%
# Epoch 17/30 - Evaluation
# [========================================] 157/157 | Loss: 1.928 | Accuracy: 34.26%
# Train Loss: 1.9634, Train Acc: 33.95%
# Validation Loss: 1.9283, Validation Acc: 34.26%
#
# Epoch 18/30 - Training
# [========================================] 782/782 | Loss: 1.959 | Accuracy: 33.65%
# Epoch 18/30 - Evaluation
# [========================================] 157/157 | Loss: 2.081 | Accuracy: 31.21%
# Train Loss: 1.9589, Train Acc: 33.65%
# Validation Loss: 2.0806, Validation Acc: 31.21%
#
# Epoch 19/30 - Training
# [========================================] 782/782 | Loss: 1.970 | Accuracy: 33.46%
# Epoch 19/30 - Evaluation
# [========================================] 157/157 | Loss: 2.005 | Accuracy: 32.89%
# Train Loss: 1.9695, Train Acc: 33.46%
# Validation Loss: 2.0054, Validation Acc: 32.89%
#
# Epoch 20/30 - Training
# [========================================] 782/782 | Loss: 1.962 | Accuracy: 33.56%
# Epoch 20/30 - Evaluation
# [========================================] 157/157 | Loss: 1.944 | Accuracy: 35.14%
# Train Loss: 1.9617, Train Acc: 33.56%
# Validation Loss: 1.9442, Validation Acc: 35.14%
#
# Epoch 21/30 - Training
# [========================================] 782/782 | Loss: 1.963 | Accuracy: 33.66%
# Epoch 21/30 - Evaluation
# [========================================] 157/157 | Loss: 2.082 | Accuracy: 31.85%
# Train Loss: 1.9628, Train Acc: 33.66%
# Validation Loss: 2.0816, Validation Acc: 31.85%
#
# Epoch 22/30 - Training
# [========================================] 782/782 | Loss: 1.961 | Accuracy: 33.62%
# Epoch 22/30 - Evaluation
# [========================================] 157/157 | Loss: 1.946 | Accuracy: 33.96%
# Train Loss: 1.9609, Train Acc: 33.62%
# Validation Loss: 1.9461, Validation Acc: 33.96%
#
# Epoch 23/30 - Training
# [========================================] 782/782 | Loss: 1.961 | Accuracy: 33.76%
# Epoch 23/30 - Evaluation
# [========================================] 157/157 | Loss: 1.926 | Accuracy: 33.37%
# Train Loss: 1.9606, Train Acc: 33.76%
# Validation Loss: 1.9265, Validation Acc: 33.37%
#
# Epoch 24/30 - Training
# [========================================] 782/782 | Loss: 1.973 | Accuracy: 33.43%
# Epoch 24/30 - Evaluation
# [========================================] 157/157 | Loss: 1.930 | Accuracy: 33.50%
# Train Loss: 1.9734, Train Acc: 33.43%
# Validation Loss: 1.9303, Validation Acc: 33.50%
#
# Epoch 25/30 - Training
# [========================================] 782/782 | Loss: 1.955 | Accuracy: 34.09%
# Epoch 25/30 - Evaluation
# [========================================] 157/157 | Loss: 1.987 | Accuracy: 33.19%
# Train Loss: 1.9551, Train Acc: 34.09%
# Validation Loss: 1.9867, Validation Acc: 33.19%
#
# Epoch 26/30 - Training
# [========================================] 782/782 | Loss: 1.974 | Accuracy: 33.38%
# Epoch 26/30 - Evaluation
# [========================================] 157/157 | Loss: 1.949 | Accuracy: 32.99%
# Train Loss: 1.9735, Train Acc: 33.38%
# Validation Loss: 1.9487, Validation Acc: 32.99%
#
# Epoch 27/30 - Training
# [========================================] 782/782 | Loss: 1.957 | Accuracy: 34.03%
# Epoch 27/30 - Evaluation
# [========================================] 157/157 | Loss: 1.995 | Accuracy: 33.28%
# Train Loss: 1.9575, Train Acc: 34.03%
# Validation Loss: 1.9946, Validation Acc: 33.28%
#
# Epoch 28/30 - Training
# [========================================] 782/782 | Loss: 1.960 | Accuracy: 33.48%
# Epoch 28/30 - Evaluation
# [========================================] 157/157 | Loss: 1.997 | Accuracy: 33.46%
# Train Loss: 1.9602, Train Acc: 33.48%
# Validation Loss: 1.9974, Validation Acc: 33.46%
#
# Epoch 29/30 - Training
# [========================================] 782/782 | Loss: 1.961 | Accuracy: 33.60%
# Epoch 29/30 - Evaluation
# [========================================] 157/157 | Loss: 1.966 | Accuracy: 33.81%
# Train Loss: 1.9608, Train Acc: 33.60%
# Validation Loss: 1.9663, Validation Acc: 33.81%
#
# Epoch 30/30 - Training
# [========================================] 782/782 | Loss: 1.968 | Accuracy: 33.75%
# Epoch 30/30 - Evaluation
# [========================================] 157/157 | Loss: 1.991 | Accuracy: 32.39%
# Train Loss: 1.9681, Train Acc: 33.75%
# Validation Loss: 1.9906, Validation Acc: 32.39%
#
# Training complete in 14m 12s.

# %%
plot_result(result_kan)

# %%
lr = 0.0001

shallow_kan = KAN([input_dim * input_dim * 3, classes], grid_size=10)

total_params_kan, trainable_params_kan = count_parameters(shallow_kan)
print(f"Total parameters: {total_params_kan}")
print(f"Trainable parameters: {trainable_params_kan}")

optimizer = optim.AdamW(shallow_kan.parameters(), lr=lr, weight_decay=0.01)
criterion = nn.CrossEntropyLoss()
# Out:
# Total parameters: 460800
# Trainable parameters: 460800

# %%
result_kan = train_model(shallow_kan, trainloader, valloader, device,
                                  optimizer, criterion,
                                  epochs, input_dim)
# Out:
# Epoch 1/30 - Training
# [========================================] 782/782 | Loss: 2.006 | Accuracy: 29.02%
# Epoch 1/30 - Evaluation
# [========================================] 157/157 | Loss: 1.924 | Accuracy: 32.54%
# Train Loss: 2.0059, Train Acc: 29.02%
# Validation Loss: 1.9240, Validation Acc: 32.54%
#
# Epoch 2/30 - Training
# [========================================] 782/782 | Loss: 1.919 | Accuracy: 32.91%
# Epoch 2/30 - Evaluation
# [========================================] 157/157 | Loss: 1.880 | Accuracy: 34.09%
# Train Loss: 1.9187, Train Acc: 32.91%
# Validation Loss: 1.8798, Validation Acc: 34.09%
#
# Epoch 3/30 - Training
# [========================================] 782/782 | Loss: 1.890 | Accuracy: 33.58%
# Epoch 3/30 - Evaluation
# [========================================] 157/157 | Loss: 1.867 | Accuracy: 34.30%
# Train Loss: 1.8904, Train Acc: 33.58%
# Validation Loss: 1.8666, Validation Acc: 34.30%
#
# Epoch 4/30 - Training
# [========================================] 782/782 | Loss: 1.873 | Accuracy: 34.50%
# Epoch 4/30 - Evaluation
# [========================================] 157/157 | Loss: 1.848 | Accuracy: 34.73%
# Train Loss: 1.8725, Train Acc: 34.50%
# Validation Loss: 1.8483, Validation Acc: 34.73%
#
# Epoch 5/30 - Training
# [========================================] 782/782 | Loss: 1.857 | Accuracy: 35.06%
# Epoch 5/30 - Evaluation
# [========================================] 157/157 | Loss: 1.837 | Accuracy: 35.74%
# Train Loss: 1.8574, Train Acc: 35.06%
# Validation Loss: 1.8374, Validation Acc: 35.74%
#
# Epoch 6/30 - Training
# [========================================] 782/782 | Loss: 1.849 | Accuracy: 35.27%
# Epoch 6/30 - Evaluation
# [========================================] 157/157 | Loss: 1.829 | Accuracy: 36.48%
# Train Loss: 1.8489, Train Acc: 35.27%
# Validation Loss: 1.8292, Validation Acc: 36.48%
#
# Epoch 7/30 - Training
# [========================================] 782/782 | Loss: 1.839 | Accuracy: 35.65%
# Epoch 7/30 - Evaluation
# [========================================] 157/157 | Loss: 1.822 | Accuracy: 36.43%
# Train Loss: 1.8395, Train Acc: 35.65%
# Validation Loss: 1.8223, Validation Acc: 36.43%
#
# Epoch 8/30 - Training
# [========================================] 782/782 | Loss: 1.836 | Accuracy: 36.00%
# Epoch 8/30 - Evaluation
# [========================================] 157/157 | Loss: 1.827 | Accuracy: 35.82%
# Train Loss: 1.8364, Train Acc: 36.00%
# Validation Loss: 1.8270, Validation Acc: 35.82%
#
# Epoch 9/30 - Training
# [========================================] 782/782 | Loss: 1.830 | Accuracy: 36.10%
# Epoch 9/30 - Evaluation
# [========================================] 157/157 | Loss: 1.818 | Accuracy: 36.82%
# Train Loss: 1.8297, Train Acc: 36.10%
# Validation Loss: 1.8179, Validation Acc: 36.82%
#
# Epoch 10/30 - Training
# [========================================] 782/782 | Loss: 1.825 | Accuracy: 36.43%
# Epoch 10/30 - Evaluation
# [========================================] 157/157 | Loss: 1.815 | Accuracy: 36.52%
# Train Loss: 1.8253, Train Acc: 36.43%
# Validation Loss: 1.8154, Validation Acc: 36.52%
#
# Epoch 11/30 - Training
# [========================================] 782/782 | Loss: 1.822 | Accuracy: 36.63%
# Epoch 11/30 - Evaluation
# [========================================] 157/157 | Loss: 1.813 | Accuracy: 36.63%
# Train Loss: 1.8223, Train Acc: 36.63%
# Validation Loss: 1.8133, Validation Acc: 36.63%
#
# Epoch 12/30 - Training
# [========================================] 782/782 | Loss: 1.818 | Accuracy: 36.50%
# Epoch 12/30 - Evaluation
# [========================================] 157/157 | Loss: 1.803 | Accuracy: 37.16%
# Train Loss: 1.8179, Train Acc: 36.50%
# Validation Loss: 1.8028, Validation Acc: 37.16%
#
# Epoch 13/30 - Training
# [========================================] 782/782 | Loss: 1.818 | Accuracy: 36.77%
# Epoch 13/30 - Evaluation
# [========================================] 157/157 | Loss: 1.812 | Accuracy: 36.32%
# Train Loss: 1.8184, Train Acc: 36.77%
# Validation Loss: 1.8117, Validation Acc: 36.32%
#
# Epoch 14/30 - Training
# [========================================] 782/782 | Loss: 1.814 | Accuracy: 36.87%
# Epoch 14/30 - Evaluation
# [========================================] 157/157 | Loss: 1.816 | Accuracy: 36.58%
# Train Loss: 1.8136, Train Acc: 36.87%
# Validation Loss: 1.8155, Validation Acc: 36.58%
#
# Epoch 15/30 - Training
# [========================================] 782/782 | Loss: 1.812 | Accuracy: 36.91%
# Epoch 15/30 - Evaluation
# [========================================] 157/157 | Loss: 1.803 | Accuracy: 36.85%
# Train Loss: 1.8119, Train Acc: 36.91%
# Validation Loss: 1.8033, Validation Acc: 36.85%
#
# Epoch 16/30 - Training
# [========================================] 782/782 | Loss: 1.806 | Accuracy: 36.99%
# Epoch 16/30 - Evaluation
# [========================================] 157/157 | Loss: 1.796 | Accuracy: 37.50%
# Train Loss: 1.8057, Train Acc: 36.99%
# Validation Loss: 1.7964, Validation Acc: 37.50%
#
# Epoch 17/30 - Training
# [========================================] 782/782 | Loss: 1.807 | Accuracy: 37.11%
# Epoch 17/30 - Evaluation
# [========================================] 157/157 | Loss: 1.808 | Accuracy: 37.11%
# Train Loss: 1.8071, Train Acc: 37.11%
# Validation Loss: 1.8085, Validation Acc: 37.11%
#
# Epoch 18/30 - Training
# [========================================] 782/782 | Loss: 1.805 | Accuracy: 37.20%
# Epoch 18/30 - Evaluation
# [========================================] 157/157 | Loss: 1.801 | Accuracy: 37.49%
# Train Loss: 1.8047, Train Acc: 37.20%
# Validation Loss: 1.8009, Validation Acc: 37.49%
#
# Epoch 19/30 - Training
# [========================================] 782/782 | Loss: 1.805 | Accuracy: 37.38%
# Epoch 19/30 - Evaluation
# [========================================] 157/157 | Loss: 1.809 | Accuracy: 36.98%
# Train Loss: 1.8050, Train Acc: 37.38%
# Validation Loss: 1.8095, Validation Acc: 36.98%
#
# Epoch 20/30 - Training
# [========================================] 782/782 | Loss: 1.805 | Accuracy: 37.12%
# Epoch 20/30 - Evaluation
# [========================================] 157/157 | Loss: 1.799 | Accuracy: 37.44%
# Train Loss: 1.8049, Train Acc: 37.12%
# Validation Loss: 1.7988, Validation Acc: 37.44%
#
# Epoch 21/30 - Training
# [========================================] 782/782 | Loss: 1.802 | Accuracy: 37.37%
# Epoch 21/30 - Evaluation
# [========================================] 157/157 | Loss: 1.809 | Accuracy: 36.65%
# Train Loss: 1.8022, Train Acc: 37.37%
# Validation Loss: 1.8092, Validation Acc: 36.65%
#
# Epoch 22/30 - Training
# [========================================] 782/782 | Loss: 1.803 | Accuracy: 37.28%
# Epoch 22/30 - Evaluation
# [========================================] 157/157 | Loss: 1.803 | Accuracy: 36.69%
# Train Loss: 1.8035, Train Acc: 37.28%
# Validation Loss: 1.8027, Validation Acc: 36.69%
#
# Epoch 23/30 - Training
# [========================================] 782/782 | Loss: 1.798 | Accuracy: 37.35%
# Epoch 23/30 - Evaluation
# [========================================] 157/157 | Loss: 1.797 | Accuracy: 37.37%
# Train Loss: 1.7978, Train Acc: 37.35%
# Validation Loss: 1.7971, Validation Acc: 37.37%
#
# Epoch 24/30 - Training
# [========================================] 782/782 | Loss: 1.802 | Accuracy: 37.41%
# Epoch 24/30 - Evaluation
# [========================================] 157/157 | Loss: 1.800 | Accuracy: 36.39%
# Train Loss: 1.8017, Train Acc: 37.41%
# Validation Loss: 1.8003, Validation Acc: 36.39%
#
# Epoch 25/30 - Training
# [========================================] 782/782 | Loss: 1.798 | Accuracy: 37.51%
# Epoch 25/30 - Evaluation
# [========================================] 157/157 | Loss: 1.805 | Accuracy: 36.65%
# Train Loss: 1.7980, Train Acc: 37.51%
# Validation Loss: 1.8048, Validation Acc: 36.65%
#
# Epoch 26/30 - Training
# [========================================] 782/782 | Loss: 1.795 | Accuracy: 37.96%
# Epoch 26/30 - Evaluation
# [========================================] 157/157 | Loss: 1.802 | Accuracy: 37.20%
# Train Loss: 1.7945, Train Acc: 37.96%
# Validation Loss: 1.8022, Validation Acc: 37.20%
#
# Epoch 27/30 - Training
# [========================================] 782/782 | Loss: 1.800 | Accuracy: 37.59%
# Epoch 27/30 - Evaluation
# [========================================] 157/157 | Loss: 1.801 | Accuracy: 36.84%
# Train Loss: 1.7996, Train Acc: 37.59%
# Validation Loss: 1.8012, Validation Acc: 36.84%
#
# Epoch 28/30 - Training
# [========================================] 782/782 | Loss: 1.794 | Accuracy: 37.44%
# Epoch 28/30 - Evaluation
# [========================================] 157/157 | Loss: 1.802 | Accuracy: 36.66%
# Train Loss: 1.7943, Train Acc: 37.44%
# Validation Loss: 1.8022, Validation Acc: 36.66%
#
# Epoch 29/30 - Training
# [========================================] 782/782 | Loss: 1.793 | Accuracy: 37.83%
# Epoch 29/30 - Evaluation
# [========================================] 157/157 | Loss: 1.792 | Accuracy: 37.59%
# Train Loss: 1.7931, Train Acc: 37.83%
# Validation Loss: 1.7919, Validation Acc: 37.59%
#
# Epoch 30/30 - Training
# [========================================] 782/782 | Loss: 1.796 | Accuracy: 37.58%
# Epoch 30/30 - Evaluation
# [========================================] 157/157 | Loss: 1.794 | Accuracy: 37.63%
# Train Loss: 1.7958, Train Acc: 37.58%
# Validation Loss: 1.7944, Validation Acc: 37.63%
#
# Training complete in 14m 37s.

# %%
plot_result(result_kan)
